# %% [markdown]
# Source of data sets:
# - covid-19 related datasets: https://www.kaggle.com/sudalairajkumar/novel-corona-virus-2019-dataset/discussion/136061
# - population_by_country: https://www.kaggle.com/tanuprabhu/population-by-country-2020

# %%
import os
import zipfile
import datetime
from datetime import timedelta

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import datetime as dt

#import requests, zipfile

import geopandas as gpd
import descartes


# %matplotlib inline
pd.set_option('display.max_columns', 50)
pd.set_option('display.max_rows', 100)

# %% [markdown]
# We will download covid-19 data programmatically. Currently there are updates on a daily basis.
#
# We will follow these steps:
#
# - Rename current file `data/covid_19_data.csv` by adding a `yymmdd` date extension to the file name and thereby, in effect, archiving it.
# - Download new file. Currently it comes compressed as a zip file, hence our target file is extracted and the zip file gets deleted.

# %%
# Setting file name and path of data files

# 1) The covid_19 data file

DATA_FOLDER_PATH = os.path.join(os.path.curdir, 'data')
DATA_NAME = 'covid_19_data.csv'
DATA_PATH = os.path.join(DATA_FOLDER_PATH, DATA_NAME)

# 2) The population data file

POPDATA_NAME = 'population_2020_for_johnhopkins_data.csv'
POPDATA_PATH = os.path.join(DATA_FOLDER_PATH, POPDATA_NAME)

# Making sure we have the correct path to the data. 
# This should be the case if this notebook was opened 
# in the root directory of the web app

required_data_path = './data/covid_19_data.csv'
required_popdata_path = './data/population_2020_for_johnhopkins_data.csv'

assert DATA_PATH == required_data_path, 'Error: Working directory must be the root directory of the web app'
print('Great. The path is correct for the covid-19 data.')
assert POPDATA_PATH == required_popdata_path, 'Error: Working directory must be the root directory of the web app'

print('Great. The path is correct for the population data.')
# Out:
# Great. The path is correct for the covid-19 data.
# Great. The path is correct for the population data.

# %% [markdown]
# Next we create three functions, that we will help us in the chore of updating the covid-19 data.

# %%
def archive_data(data_name, data_folder_path):
    '''
    This function archives the old data file by renaming it with a date suffix in the format yymmdd,
    and then it prints a confirmation that the old data was archived including the name of the archived file
    
    Args:
        file_name (str): name of covid-19 data file
        file_path (str): path to covid-19 data file

    Returns:
        this function does not return anything
    '''

    file_full_path = os.path.join(data_folder_path, data_name)

    try:
        mtime = os.path.getmtime(file_full_path)
        last_modified_time = datetime.datetime.fromtimestamp(mtime) 
        last_data_date = last_modified_time - timedelta(days=1)
        date_extention = str(last_data_date.year)[2:].zfill(2) + str(last_data_date.month).zfill(2) + str(last_data_date.day).zfill(2)
        new_file_name = file_name[:-4] + date_extention + file_name[-4:]
        new_file_full_path = os.path.join(file_path, new_file_name)
        os.rename(file_full_path, new_file_full_path)
        print("- Old data file archived as: '{}'".format(new_file_name))
        print()
    except OSError:
        mtime = 0

# %%
def download_data(file_name, file_path):
    '''
    This function programmatically downloads the new data file from kaggle to the 'data' folder
    in the root directory of the web app. The new data file is compressed into .zip format
    
    Args:
        file_name (str): name of covid-19 data file
        file_path (str): path to covid-19 data file

    Returns:
        this function does not return anything
    '''
    
    # !kaggle datasets download -d sudalairajkumar/novel-corona-virus-2019-dataset -f $file_name -p $file_path --force

# %%
def extract_zip_file(file_name, file_path):
    '''
    This function unzips the compressed new data file found in the 'data' folder
    in the root directory of the web app. Then the zip file is deleted.
    
    Args:
        file_name (str): name of covid-19 data file
        file_path (str): path to covid-19 data file

    Returns:
        this function does not return anything
    '''
    
    for i,file in enumerate(os.listdir(file_path)):
        # looping through the files in the data folder, we search for the one ending with ".zip"
        if file.endswith(".zip"):
            try:
                # we obtain the zip file name, its full path and unzip it in the same folder
                zip_file_name = os.path.basename(file)
                zip_full_path = os.path.join(file_path, zip_file_name)
                
                with zipfile.ZipFile(zip_full_path, 'r') as zip_ref:
                    zip_ref.extractall(file_path)
                
                print()
                print("- New file extracted from compressed file to data folder as: '{}'".format(file_name))
                print()
                os.remove(zip_full_path)
                print('- Zip file deleted post extraction.')
            except OSError:
                pass

# %% [markdown]
# We utilize the above three functions in our main function for updating the covid-19 data: `get_latest_data()`

# %%
def get_latest_data(file_name, file_path):
    
    '''
    This function is our main function for updating the covid-10 data. It will utilize our
    three helper functions 'archive_data()', 'download_data()' and 'extract_zipfile()' for completing 
    a sequence of tasks:
    
    - Rename current file data/covid_19_data.csv by adding a yymmdd date extension to the file name 
    and thereby, in effect, archiving it.
    - Download new file, which is compressed into .zip format
    - Extract data file 'covid_19_data.csv' from zip-file
    - Delete zip-file
    
    For each task in the sequence a confirmation is printed.
    Finally, a confirmation is printed once the full sequence is successfully completed: 
    'COMPLETED sequence for updating data successfully!'
    
    Args:
        file_name (str): name of covid-19 data file
        file_path (str): path to covid-19 data file

    Returns:
        this function does not return anything
    '''
    
    file_full_path = os.path.join(file_path, file_name)

    try:
        # get the time of last modification of the specified path; the getmtime method returns 
        # a floating point value which represents the number of seconds since the epoch. 
        # This method raise OSError if the file does not exist or is somehow inaccessible.
        mtime = os.path.getmtime(file_full_path)
        
        # converting floating point value to a datetime date
        last_modified_date = datetime.datetime.fromtimestamp(mtime).date()
        
        # compare last_modified_date of current file with today's date and only initiate sequence 
        # if the current data file is indeed old, ie. it was last modified yesterday or earlier
        today_date = datetime.date.today()
        
        if last_modified_date == today_date:
            print("We already have the latest data")
            
        elif last_modified_date < today_date:
            print('STARTING sequence for updating data...')
            print()
            
            archive_data(file_name, file_path)
            
            download_data(file_name, file_path)
            
            extract_zip_file(file_name, file_path)
            
            print()
            print('COMPLETED sequence for updating data successfully!')
        else:
            print('Error: Not able to comprehend; last_modified_date set to the future')
        
    except OSError:
        print('Error: Not able to extract meta data for provided file_name/file_path')

# %% [markdown]
# Running the below cell initiates the sequence of updating the covid-19 data:

# %%
# update data
get_latest_data(FILE_NAME, FILE_PATH)
# Out:
# STARTING sequence for updating data...
#
# - Old data file archived as: 'covid_19_data200701.csv'
#
# Downloading 494724%2F1310261%2Fcompressed%2Fcovid_19_data.csv.zip to ./data
# 100%|████████████████████████████████████████| 848k/848k [00:00<00:00, 5.16MB/s]
# 100%|████████████████████████████████████████| 848k/848k [00:00<00:00, 5.15MB/s]
#
# - New file extracted from compressed file to data folder as: 'covid_19_data.csv'
#
# - Zip file deleted post extraction.
#
# COMPLETED sequence for updating data successfully!

# %%
def get_pop_data():
    
    pop_dataset_path = 'data/population_2020_for_johnhopkins_data.csv'
    
    df_pop = pd.read_csv(pop_dataset_path, delimiter=";") # population dataset
    
    # setting column headers
    df_pop.columns = ['Country', 'Short', 'Continent', 'Population', 'PopKm2', 'MedianAge', 'UrbanPopPercent']
    
    # extracting the ratio from string column 'UrbanPopPercent' and replacing it with a new column with
    # float values for ratio.
    df_pop['UrbanPopRatio'] = df_pop['UrbanPopPercent'].str.strip('%').astype(float).div(100)
    df_pop.drop('UrbanPopPercent', axis = 1, inplace=True)
    
    return df_pop

# %%
df_pop = get_pop_data('data/population_2020_for_johnhopkins_data.csv')
df_pop.head()
# Out:
#        Country Short Continent  Population  PopKm2  MedianAge  UrbanPopRatio
# 0  Afghanistan   AFG      Asia    38928346      60         18           0.25
# 1      Albania   ALB    Europe     2877797     105         36           0.63
# 2      Algeria   DZA    Africa    43851044      18         29           0.73
# 3       Angola   AGO    Africa    32866272      26         17           0.67
# 4    Argentina   ARG   America    45195774      17         32           0.93

# %%
def include_pop_data():
    pop_dataset_path = 'data/population_2020_for_johnhopkins_data.csv'
    data_path = 'data/covid_19_data.csv'

# %%
def df_prepare(dataset, pop_dataset=None, historical=False, continent=None, top_n = None):
    
    '''
    Clean data, join with population data (optional) and return dataframe.
    
    Args:
        dataset (str): path of the csv data file
        
        
    Return:
    
        df (DataFrame): pre-prepared data for geoplot / clean data for barplot and timeplot
        
    '''
    
    # read datasets
    
    df = pd.read_csv(dataset) #
    
    if pop_dataset:
        
        df_pop = pd.read_csv(pop_dataset, delimiter=";") # population dataset
        
    
    # clean data
    
    df = df.rename(columns={"ObservationDate": "Date", "Country/Region": "Country"})
    
    df = df.groupby(['Country', 'Date']).sum().reset_index()
    
    
    df['Country'] = df['Country'].replace({'UK': 'United Kingdom', 
                                           'US': 'United States', 
                                           'Mainland China': 'China',
                                           'Czech Republic': 'Czechia',
                                           })
    
    
    
    if pop_dataset:
    
        df = df.set_index('Country').join(df_pop.set_index('Country'))
        df.dropna(subset=['Population'], inplace=True)
        
        df['Infected'] = df['Confirmed'] - df['Recovered'] - df['Deaths']
        
        df['Confirmed_percent'] = 100*df['Confirmed']/(df['Population'] + 1.0)
        df['Recovered_percent'] = 100*df['Recovered']/(df['Population'] + 1.0)
        df['Deaths_percent'] = 100*df['Deaths']/(df['Population'] + 1.0)
        df['Infected_percent'] = 100*df['Infected']/(df['Population'] + 1.0)
        
        df['Confirmed_per_100k'] = 100000*df['Confirmed']/(df['Population'] + 1.0)
        df['Recovered_per_100k'] = 100000*df['Recovered']/(df['Population'] + 1.0)
        df['Deaths_per_100k'] = 100000*df['Deaths']/(df['Population'] + 1.0)
        df['Infected_per_100k'] = 100000*df['Infected']/(df['Population'] + 1.0)
    
    # filter/select data based on continent, selected_countries and historical
    
        if continent:
            df = df[df['Continent'] == continent]
    
    #df = df.loc[df.index.isin(selected_countries), :]
    
    df = df.reset_index().set_index('Date')
    df.index = pd.to_datetime(df.index, infer_datetime_format=True)

    if historical:
        
        df = df.query("index >= '2020-02-20'")
        
        #df = df[['Continent', 'Country', 'Population', 'Infected', 'Recovered', 'Deaths', 
        #         'Infected_percent', 'Recovered_percent', 'Deaths_percent',
        #         'Infected_per_100k', 'Recovered_per_100k', 'Deaths_per_100k']]
        
    else:
    
        df = df[df.index == df.index.max()]
        if pop_dataset:
            #df = df[['Continent', 'Country', 'Short', 'Population', 'Infected', 'Recovered', 'Deaths', 
            #         'Infected_percent', 'Recovered_percent', 'Deaths_percent',
            #         'Infected_per_100k', 'Recovered_per_100k', 'Deaths_per_100k']]
            
            df = df.reset_index().set_index('Country')
        else:
            #df = df[['Continent', 'Country', 'Population', 'Infected', 'Recovered', 'Deaths', 
            #         'Infected_percent', 'Recovered_percent', 'Deaths_percent',
            #         'Infected_per_100k', 'Recovered_per_100k', 'Deaths_per_100k']]
            
            df = df.reset_index().set_index('Country')
    
    
    return df

# %%
df_01 = df_prepare('data/covid_19_data.csv', 'data/population_2020_for_johnhopkins_data.csv',
                    historical = False,
                    continent = None)
df_01.head()
# Out:
#                   Date    SNo  Confirmed  Deaths  Recovered Short Continent  \
# Country
# Afghanistan 2020-07-05  56844    32951.0   864.0    19366.0   AFG      Asia
# Albania     2020-07-05  56845     2893.0    76.0     1657.0   ALB    Europe
# Algeria     2020-07-05  56846    15941.0   952.0    11492.0   DZA    Africa
# Angola      2020-07-05  56848      346.0    19.0      108.0   AGO    Africa
# Argentina   2020-07-05  56850    77815.0  1507.0    27597.0   ARG   America
#
#              Population  Density (P/Km²)  Med. Age Urban Pop %  Infected  \
# Country
# Afghanistan  38928346.0             60.0      18.0        25 %   12721.0
# Albania       2877797.0            105.0      36.0        63 %    1160.0
# Algeria      43851044.0             18.0      29.0        73 %    3497.0
# Angola       32866272.0             26.0      17.0        67 %     219.0
# Argentina    45195774.0             17.0      32.0        93 %   48711.0
#
#              Confirmed_percent  Recovered_percent  Deaths_percent  \
# Country
# Afghanistan           0.084645           0.049748        0.002219
# Albania               0.100528           0.057579        0.002641
# Algeria               0.036353           0.026207        0.002171
# Angola                0.001053           0.000329        0.000058
# Argentina             0.172173           0.061061        0.003334
#
#              Infected_percent  Confirmed_per_100k  Recovered_per_100k  \
# Country
# Afghanistan          0.032678           84.645259           49.747810
# Albania              0.040309          100.528251           57.578746
# Algeria              0.007975           36.352611           26.206901
# Angola               0.000666            1.052751            0.328604
# Argentina            0.107778          172.173173           61.061017
#
#              Deaths_per_100k  Infected_per_100k
# Country
# Afghanistan         2.219462          32.677987
# Albania             2.640908          40.308597
# Algeria             2.170986           7.974724
# Angola              0.057810           0.666337
# Argentina           3.334382         107.777773

# %%
df_01.columns
# Out:
# Index(['Date', 'Continent', 'Short', 'Population', 'Infected', 'Recovered',
#        'Deaths', 'Infected_percent', 'Recovered_percent', 'Deaths_percent',
#        'Infected_per_100k', 'Recovered_per_100k', 'Deaths_per_100k'],
#       dtype='object')

# %%
df_02 = df_prepare('data/covid_19_data.csv', 'data/population_2020_for_johnhopkins_data.csv',
                    historical = True,
                    continent = 'Africa')
df_02.head()
# Out:
#             Country   SNo  Confirmed  Deaths  Recovered Short Continent  \
# Date
# 2020-02-25  Algeria  2353        1.0     0.0        0.0   DZA    Africa
# 2020-02-26  Algeria  2454        1.0     0.0        0.0   DZA    Africa
# 2020-02-27  Algeria  2558        1.0     0.0        0.0   DZA    Africa
# 2020-02-28  Algeria  2666        1.0     0.0        0.0   DZA    Africa
# 2020-02-29  Algeria  2784        1.0     0.0        0.0   DZA    Africa
#
#             Population  Density (P/Km²)  Med. Age Urban Pop %  Infected  \
# Date
# 2020-02-25  43851044.0             18.0      29.0        73 %       1.0
# 2020-02-26  43851044.0             18.0      29.0        73 %       1.0
# 2020-02-27  43851044.0             18.0      29.0        73 %       1.0
# 2020-02-28  43851044.0             18.0      29.0        73 %       1.0
# 2020-02-29  43851044.0             18.0      29.0        73 %       1.0
#
#             Confirmed_percent  Recovered_percent  Deaths_percent  \
# Date
# 2020-02-25           0.000002                0.0             0.0
# 2020-02-26           0.000002                0.0             0.0
# 2020-02-27           0.000002                0.0             0.0
# 2020-02-28           0.000002                0.0             0.0
# 2020-02-29           0.000002                0.0             0.0
#
#             Infected_percent  Confirmed_per_100k  Recovered_per_100k  \
# Date
# 2020-02-25          0.000002             0.00228                 0.0
# 2020-02-26          0.000002             0.00228                 0.0
# 2020-02-27          0.000002             0.00228                 0.0
# 2020-02-28          0.000002             0.00228                 0.0
# 2020-02-29          0.000002             0.00228                 0.0
#
#             Deaths_per_100k  Infected_per_100k
# Date
# 2020-02-25              0.0            0.00228
# 2020-02-26              0.0            0.00228
# 2020-02-27              0.0            0.00228
# 2020-02-28              0.0            0.00228
# 2020-02-29              0.0            0.00228

# %%
df_02 = df_01[['Short', 'Deaths']][:10]
df_02
# Out:
#             Short  Deaths
# Country
# Afghanistan   AFG   746.0
# Albania       ALB    62.0
# Algeria       DZA   912.0
# Angola        AGO    13.0
# Argentina     ARG  1307.0
# Armenia       ARM   443.0
# Australia     AUS   104.0
# Austria       AUT   705.0
# Azerbaijan    AZE   213.0
# Bangladesh    BGD  1847.0

# %%
df_01.iloc[:,:1].squeeze()
# Out:
# Country
# Afghanistan   2020-06-30
# Albania       2020-06-30
# Algeria       2020-06-30
# Angola        2020-06-30
# Argentina     2020-06-30
#                  ...
# Venezuela     2020-06-30
# Vietnam       2020-06-30
# Yemen         2020-06-30
# Zambia        2020-06-30
# Zimbabwe      2020-06-30
# Name: Date, Length: 143, dtype: datetime64[ns]

# %%
def plot_bar(var, continent = None, top_n = None):

    var_list_abs = ['Infected', 'Recovered', 'Deaths']
    var_list_rel1 = ['Infected_percent', 'Recovered_percent', 'Deaths_percent']
    var_list_rel2 = ['Infected_per_100k', 'Recovered_per_100k', 'Deaths_per_100k']

    continent_list = ['America', 'Europe', 'Asia', 'Africa', 'Oceania']

    if continent:
        assert continent in continent_list
    
    
    keyword1 = '_percent'
    keyword2 = '_per_100k'

    if keyword1 in var:
        
        stat = '(relative to population)'
        var_list = var_list_rel1
    
    elif keyword2 in var:
        
        stat = '(relative to population)'
        var_list = var_list_rel2
    
    else:
        stat = ''
        var_list = var_list_abs
        

    df = df_prepare('data/covid_19_data.csv', 'data/population_2020_for_johnhopkins_data.csv',
                    historical = False,
                    continent = continent)


    if continent == 'Oceania':
        fig_width = 5
    else:
        fig_width = 20
        
    if top_n:
        tot_countries = df.shape[0]
        if top_n > tot_countries:
            top_n = tot_countries
            
    if not continent:
        continent = "The World"
    
    df.sort_values(by=[var], ascending=False).loc[:, var_list][:top_n].plot.bar(
        title = '{}: Number of Infected, Recovered, Deaths {}'.format(continent, stat), 
        stacked = False,
        colormap='tab20b',
        figsize=(fig_width, 5)
        )
    
    plt.xticks(rotation=20)
    plt.legend(loc='upper right');
    
    #return df

# %%
df = df_prepare('data/covid_19_data.csv', 'data/population_2020_for_johnhopkins_data.csv',
                    historical = False,
                    continent = 'Africa')

# %%
df[['Short', 'Deaths_per_100k']]
# Out:
#                          Short  Deaths_per_100k
# Country
# Algeria                    DZA         2.079768
# Angola                     AGO         0.039554
# Benin                      BEN         0.173222
# Botswana                   BWA         0.044364
# Burkina Faso               BFA         0.253549
# Burundi                    BDI         0.008410
# Cameroon                   CMR         1.179091
# Central African Republic   CAF         0.973132
# Chad                       TCD         0.450509
# Congo (Kinshasa)           COD         0.189814
# Egypt                      EGY         2.885638
# Eritrea                    ERI         0.000000
# Ethiopia                   ETH         0.089594
# Ghana                      GHA         0.360442
# Guinea                     GIN         0.251279
# Kenya                      KEN         0.275240
# Liberia                    LBR         0.711789
# Libya                      LBY         0.349279
# Madagascar                 MDG         0.072226
# Malawi                     MWI         0.073184
# Mali                       MLI         0.572816
# Mauritania                 MRT         2.774397
# Morocco                    MAR         0.617709
# Mozambique                 MOZ         0.019197
# Namibia                    NAM         0.000000
# Niger                      NER         0.276784
# Nigeria                    NGA         0.286214
# Rwanda                     RWA         0.015441
# Senegal                    SEN         0.668899
# Sierra Leone               SLE         0.752164
# Somalia                    SOM         0.566279
# South Africa               ZAF         4.479951
# South Sudan                SDS         0.339476
# Sudan                      SDN         1.304469
# Tanzania                   TZA         0.035156
# Togo                       TGO         0.169108
# Tunisia                    TUN         0.423061
# Uganda                     UGA         0.000000
# Zambia                     ZMB         0.130549
# Zimbabwe                   ZWE         0.047097

# %%
def plot_bar2(var, continent = None, top_n = None):

    var_list_abs = ['Infected', 'Recovered', 'Deaths']
    var_list_rel1 = ['Infected_percent', 'Recovered_percent', 'Deaths_percent']
    var_list_rel2 = ['Infected_per_100k', 'Recovered_per_100k', 'Deaths_per_100k']

    continent_list = ['America', 'Europe', 'Asia', 'Africa', 'Oceania']

    if continent:
        assert continent in continent_list
    
    
    keyword1 = '_percent'
    keyword2 = '_per_100k'

    if keyword1 in var:
        
        stat = '(relative to population)'
        var_list = var_list_rel1
    
    elif keyword2 in var:
        
        stat = '(relative to population)'
        var_list = var_list_rel2
    
    else:
        stat = ''
        var_list = var_list_abs
        

    df = df_prepare('data/covid_19_data.csv', 'data/population_2020_for_johnhopkins_data.csv',
                    historical = False,
                    continent = continent)
        
    if top_n:
        tot_countries = df.shape[0]
        if top_n > tot_countries:
            top_n = tot_countries
            
    if not continent:
        continent = "The World"
    
    df = df.sort_values(by=[var], ascending=False).loc[:, var_list][:top_n].reset_index()
    
    return df

# %%
df_all = plot_bar2('Infected_per_100k', continent = '', top_n = 20)
df_all
# Out:
#             Country  Infected_per_100k  Recovered_per_100k  Deaths_per_100k
# 0            Sweden         532.810998            0.000000        50.716557
# 1     United States         468.787785          193.411743        36.374935
# 2    United Kingdom         386.983993            1.947382        62.945221
# 3           Armenia         374.488230          308.142023        12.148848
# 4              Peru         315.129373          440.739534        24.939452
# 5           Belgium         294.082017          144.707024        83.661040
# 6              Oman         284.551819          321.307979         2.682788
# 7            Panama         268.079303          339.856048        12.074809
# 8       Netherlands         254.282597            1.085506        35.652438
# 9           Belarus         219.581845          401.330296         3.714551
# 10           Brazil         213.334702          283.090726        24.120785
# 11            Chile         193.887886         1074.465524        23.550703
# 12           Kuwait         191.801005          743.928448         7.727302
# 13           Russia         164.061316          235.617409         5.616220
# 14          Bolivia         161.192192           50.175524         7.024745
# 15     Saudi Arabia         156.612858          302.106586         3.754251
# 16          Moldova         145.365700          198.787099        11.898966
# 17            Spain         145.020469          321.627015        60.579904
# 18  North Macedonia         142.797144           94.750105        11.855763
# 19           France         142.445223          114.496674        45.448757

# %%
plot_bar('Infected_per_100k', continent = '', top_n = 20)

# %%
def plot_time(var, continent=None, top_n = None):


    df = df_prepare('data/covid_19_data.csv', 'data/population_2020_for_johnhopkins_data.csv',
                    historical = True,
                    continent = continent)

    # initializing the plot of df
    dic = dict()

    y = var
    group = 'Country'

    tot_countries = df.shape[0]
    
    if top_n:
        if top_n > tot_countries:
            top_n = tot_countries
    else:
        top_n = tot_countries
    
    
    
    fig, ax = plt.subplots()
    # key gives the group name (i.e. category), data gives the actual values

    last_date = df.index.max()
    
    df_last = df[df.index == last_date].sort_values(var, ascending=False)
    country_list = list(df_last[group][:top_n])
    
    for key, data in df.groupby(group):
        
        if key in country_list:
            
            data.plot(y=y, ax=ax, label=key, figsize=(15,8))

            dic[key] = data[y].iloc[-1]
        


    # re-arranging the order of lables, so that it matches the end points of the graphs
    current_handles, current_labels = plt.gca().get_legend_handles_labels()

    mydf = pd.DataFrame.from_dict(dic, orient='index', columns = [y])

    mydf['handles'] = current_handles
    mydf['labels'] = current_labels
    mydf = mydf.sort_values(by=[y], ascending=False)

    new_handles = list(mydf['handles'])
    new_labels = list(mydf['labels'])

    plt.legend(new_handles,new_labels)


    if not continent:
        continent = "The World"

    plt.title('{}: {} per Country'.format(continent, var))
    plt.ylabel('{}'.format(var));

# %%
def prepare_time(var, continent=None, top_n = None):


    df = df_prepare('data/covid_19_data.csv', 'data/population_2020_for_johnhopkins_data.csv',
                    historical = True,
                    continent = continent)

    
    # steps to add new metrics such as death rate
    
    countries = df.Country.unique()

    for i, country in enumerate(countries):
    
        days_delay = 14
    
        if i == 0:
        
        
            df1 = df.loc[df['Country'] == country]
            df1['Deaths_n_daysago'] = df1['Deaths'].shift(days_delay)
            df1['Mortality_rate'] = 100*df1['Deaths_n_daysago'] / (df1['Recovered'] + df1['Deaths_n_daysago'])
            df1['Recovered_in_n_days'] = df1['Deaths']*(1/(df1['Mortality_rate']/100 + 0.0000001) - 1)

        elif i > 0:

            df_single = df.loc[df['Country'] == country]
            df_single['Deaths_n_daysago'] = df_single['Deaths'].shift(days_delay)
            df_single['Mortality_rate'] = 100*df_single['Deaths_n_daysago'] / (df_single['Recovered'] + df_single['Deaths_n_daysago'])
            df_single['Recovered_in_n_days'] = df_single['Deaths']*(1/(df_single['Mortality_rate']/100 + 0.0000001) - 1)

            frames = [df1, df_single]
            df1 = pd.concat(frames)
            
    df = df1
    
    
    # initializing the plot of df
    dic = dict()

    y = var
    group = 'Country'

    tot_countries = df.shape[0]
    
    if top_n:
        if top_n > tot_countries:
            top_n = tot_countries
    else:
        top_n = tot_countries
    

    last_date = df.index.max()
    
    df_last = df[df.index == last_date].sort_values(var, ascending=False)
    countrylist = list(df_last[group][:top_n])
    
    df = df.reset_index()
    
    

    return countrylist, df

# %%
countrylist, df = prepare_time('Infected_percent', '', top_n = None)
# Out:
# /Users/truls/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/truls/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/truls/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/truls/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/truls/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/truls/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df
# Out:
# 5102 2020-06-22    Europe  Germany  83783942.0    7726.0   175143.0  8899.0
#
#       Infected_percent  Recovered_percent  Deaths_percent  Infected_per_100k  \
# 4979          0.000005           0.000014        0.000000           0.004774
# 4980          0.000002           0.000017        0.000000           0.002387
# 4981          0.000002           0.000017        0.000000           0.002387
# 4982          0.000002           0.000017        0.000000           0.002387
# 4983          0.000002           0.000017        0.000000           0.002387
# ...                ...                ...             ...                ...
# 5098          0.008468           0.207494        0.010593           8.468210
# 5099          0.008880           0.207644        0.010607           8.879983
# 5100          0.008553           0.208404        0.010617           8.552951
# 5101          0.009115           0.208560        0.010617           9.115112
# 5102          0.009221           0.209041        0.010621           9.221337
#
#       Recovered_per_100k  Deaths_per_100k  Deaths_n_daysago  Mortality_rate  \
# 4979            0.014323         0.000000               NaN             NaN
# 4980            0.016710         0.000000               NaN             NaN
# 4981            0.016710         0.000000               NaN             NaN
# 4982            0.016710         0.000000               NaN             NaN
# 4983            0.016710         0.000000               NaN             NaN
# ...                  ...              ...               ...             ...
# 5098          207.494412        10.592722            8635.0        4.731974
# 5099          207.643605        10.607044            8658.0        4.740733
# 5100          208.403894        10.616593            8673.0        4.732052
# 5101          208.560249        10.616593            8685.0        4.734905
# 5102          209.041248        10.621367            8695.0        4.729708
#
#       Recovered_in_n_days
# 4979                  NaN
# 4980                  NaN
# 4981                  NaN
# 4982                  NaN
# 4983                  NaN
# ...                   ...
# 5098        178678.483206
# 5099        178573.081591
# 5100        179078.013351
# 5101        178964.750050
# 5102        179251.765161
#
# [124 rows x 16 columns]

# %%
countrylist
# Out:
# ['Sweden',
#  'United States',
#  'United Kingdom',
#  'Armenia',
#  'Peru',
#  'Belgium',
#  'Oman',
#  'Panama',
#  'Netherlands',
#  'Belarus',
#  'Brazil',
#  'Chile',
#  'Kuwait',
#  'Russia',
#  'Bolivia',
#  'Saudi Arabia',
#  'Moldova',
#  'Spain',
#  'North Macedonia',
#  'France',
#  'Ecuador',
#  'United Arab Emirates',
#  'Portugal',
#  'Honduras',
#  'Singapore',
#  'Dominican Republic',
#  'Colombia',
#  'South Africa',
#  'Canada',
#  'Argentina',
#  'Guatemala',
#  'Azerbaijan',
#  'Israel',
#  'Afghanistan',
#  'Central African Republic',
#  'Pakistan',
#  'Ukraine',
#  'Mauritania',
#  'Haiti',
#  'Iraq',
#  'Bangladesh',
#  'Egypt',
#  'Iran',
#  'Kazakhstan',
#  'Poland',
#  'Italy',
#  'Bosnia and Herzegovina',
#  'El Salvador',
#  'Romania',
#  'Albania',
#  'Turkey',
#  'Nepal',
#  'Czechia',
#  'Costa Rica',
#  'Bulgaria',
#  'Kyrgyzstan',
#  'Ireland',
#  'Philippines',
#  'Mexico',
#  'Greece',
#  'South Sudan',
#  'Cameroon',
#  'Tajikistan',
#  'India',
#  'Cyprus',
#  'Somalia',
#  'Ghana',
#  'Senegal',
#  'Estonia',
#  'Sudan',
#  'Denmark',
#  'Guinea',
#  'Hungary',
#  'Venezuela',
#  'Latvia',
#  'Indonesia',
#  'Germany',
#  'Lithuania',
#  'Serbia',
#  'Luxembourg',
#  'Nicaragua',
#  'Finland',
#  'Lebanon',
#  'Liberia',
#  'Montenegro',
#  'Libya',
#  'Norway',
#  'Paraguay',
#  'Nigeria',
#  'Sierra Leone',
#  'Uzbekistan',
#  'Algeria',
#  'Kenya',
#  'Congo (Kinshasa)',
#  'Austria',
#  'Benin',
#  'Morocco',
#  'Switzerland',
#  'Madagascar',
#  'Georgia',
#  'Rwanda',
#  'Zimbabwe',
#  'Eritrea',
#  'Mali',
#  'Ethiopia',
#  'Botswana',
#  'Jordan',
#  'South Korea',
#  'Malawi',
#  'Iceland',
#  'Togo',
#  'Croatia',
#  'Slovakia',
#  'Sri Lanka',
#  'Australia',
#  'Mozambique',
#  'Mongolia',
#  'Slovenia',
#  'Namibia',
#  'Zambia',
#  'Uruguay',
#  'Yemen',
#  'Hong Kong',
#  'Cuba',
#  'Malaysia',
#  'Tunisia',
#  'Syria',
#  'Japan',
#  'Tanzania',
#  'Burundi',
#  'Uganda',
#  'Angola',
#  'Niger',
#  'New Zealand',
#  'Chad',
#  'Burkina Faso',
#  'Thailand',
#  'China',
#  'Vietnam',
#  'Cambodia',
#  'Taiwan',
#  'Papua New Guinea',
#  'Laos']

# %%
df = df[df.Country.isin(countrylist)]

# %%
plot_time('Infected_percent', '', top_n = 15)

# %%
plot_time('Recovered_percent', 'Europe', top_n = 20)

# %%
plot_time('Deaths_percent', 'Europe', top_n = 30)

# %%
def prepare_geo():
    
    fp = 'data/ne_10m_admin_0_countries.shp'

    gdf = gpd.read_file(fp)
    
    gdf = gdf.rename(columns={"ADMIN": "Country", "ADM0_A3": "Short"})
    
    gdf = gdf[['Country', 'Short', 'geometry']]
    
    
    df_all = df_prepare('data/covid_19_data.csv', 'data/population_2020_for_johnhopkins_data.csv',
                    historical = False,
                    continent = None)
    
    
    
    df = gdf.merge(df_all, how='left', on='Short').drop(columns=['Date'])
    
    df.fillna(0, inplace = True)
    
    return df

# %% [markdown]
# ### Totals

# %%
df = df_prepare('data/covid_19_data.csv', 'data/population_2020_for_johnhopkins_data.csv',
                    historical = False,
                    continent = None)
df_tot = pd.DataFrame(df.sum()).T

df_tot = df_tot[['Population', 'Infected', 'Recovered', 'Deaths']]

# %%
df_tot['Recovered_percent'] = 100*df_tot['Recovered']/(df_tot['Population'] + 1.0)
df_tot['Deaths_percent'] = 100*df_tot['Deaths']/(df_tot['Population'] + 1.0)
df_tot['Infected_percent'] = 100*df_tot['Infected']/(df_tot['Population'] + 1.0)
df_tot['Recovered_per_100k'] = 100000*df_tot['Recovered']/(df_tot['Population'] + 1.0)
df_tot['Deaths_per_100k'] = 100000*df_tot['Deaths']/(df_tot['Population'] + 1.0)
df_tot['Infected_per_100k'] = 100000*df_tot['Infected']/(df_tot['Population'] + 1.0)

# %%
df_tot
# Out:
#     Population     Infected    Recovered  Deaths Recovered_percent  \
# 0  7.62963e+09  4.06162e+06  4.41967e+06  471491         0.0579278
#
#   Deaths_percent Infected_percent Recovered_per_100k Deaths_per_100k  \
# 0     0.00617974        0.0532349            57.9278         6.17974
#
#   Infected_per_100k
# 0           53.2349

# %% [markdown]
# ### Shift (historical)

# %%
df = df_prepare('data/covid_19_data.csv', 'data/population_2020_for_johnhopkins_data.csv',
                    historical = True,
                    continent = 'Europe')

countries = df.Country.unique()

for i, country in enumerate(countries):
    
    days_delay = 18
    
    if i == 0:
        
        
        df1 = df.loc[df['Country'] == country]
        df1['Deaths_n_daysago'] = df1['Deaths'].shift(days_delay)
        df1['Mortality_rate'] = df1['Deaths_n_daysago'] / (df1['Recovered'] + df1['Deaths_n_daysago'])
        df1['Recovered_in_n_days'] = df1['Deaths']*(1/(df1['Mortality_rate'] + 0.0000001) - 1)

    elif i > 0:
    
        df_single = df.loc[df['Country'] == country]
        df_single['Deaths_n_daysago'] = df_single['Deaths'].shift(days_delay)
        df_single['Mortality_rate'] = df_single['Deaths_n_daysago'] / (df_single['Recovered'] + df_single['Deaths_n_daysago'])
        df_single['Recovered_in_n_days'] = df_single['Deaths']*(1/(df_single['Mortality_rate'] + 0.0000001) - 1)

        frames = [df1, df_single]
 
        df1 = pd.concat(frames)
df = df1
# Out:
# /Users/truls/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
# /Users/truls/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# /Users/truls/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/truls/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/truls/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/truls/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df
# Out:
#            Continent         Country  Population  Infected  Recovered  \
# Date
# 2020-03-09    Europe         Albania   2877797.0       2.0        0.0
# 2020-03-10    Europe         Albania   2877797.0      10.0        0.0
# 2020-03-11    Europe         Albania   2877797.0      11.0        0.0
# 2020-03-12    Europe         Albania   2877797.0      22.0        0.0
# 2020-03-13    Europe         Albania   2877797.0      32.0        0.0
# ...              ...             ...         ...       ...        ...
# 2020-06-18    Europe  United Kingdom  67886011.0  258249.0     1313.0
# 2020-06-19    Europe  United Kingdom  67886011.0  259420.0     1319.0
# 2020-06-20    Europe  United Kingdom  67886011.0  260587.0     1319.0
# 2020-06-21    Europe  United Kingdom  67886011.0  261767.0     1319.0
# 2020-06-22    Europe  United Kingdom  67886011.0  262708.0     1322.0
#
#              Deaths  Infected_percent  Recovered_percent  Deaths_percent  \
# Date
# 2020-03-09      0.0          0.000069           0.000000        0.000000
# 2020-03-10      0.0          0.000347           0.000000        0.000000
# 2020-03-11      1.0          0.000382           0.000000        0.000035
# 2020-03-12      1.0          0.000764           0.000000        0.000035
# 2020-03-13      1.0          0.001112           0.000000        0.000035
# ...             ...               ...                ...             ...
# 2020-06-18  42373.0          0.380416           0.001934        0.062418
# 2020-06-19  42546.0          0.382141           0.001943        0.062673
# 2020-06-20  42674.0          0.383860           0.001943        0.062861
# 2020-06-21  42717.0          0.385598           0.001943        0.062925
# 2020-06-22  42731.0          0.386984           0.001947        0.062945
#
#             Infected_per_100k  Recovered_per_100k  Deaths_per_100k  \
# Date
# 2020-03-09           0.069498            0.000000         0.000000
# 2020-03-10           0.347488            0.000000         0.000000
# 2020-03-11           0.382237            0.000000         0.034749
# 2020-03-12           0.764473            0.000000         0.034749
# 2020-03-13           1.111961            0.000000         0.034749
# ...                       ...                 ...              ...
# 2020-06-18         380.415630            1.934125        62.417866
# 2020-06-19         382.140580            1.942963        62.672705
# 2020-06-20         383.859638            1.942963        62.861256
# 2020-06-21         385.597846            1.942963        62.924598
# 2020-06-22         386.983993            1.947382        62.945221
#
#             Deaths_n_daysago  Mortality_rate  Recovered_in_n_days
# Date
# 2020-03-09               NaN             NaN                  NaN
usa = df[df['Country'] == 'United States']

# %%
usa['Deaths_2weeksago'] = usa['Deaths'].shift(14)

# %%
usa['Death_rate'] = usa['Deaths_2weeksago'] / (usa['Recovered'] + usa['Deaths_2weeksago'])

# %%
usa['Recovered_in2weeks_est'] = usa['Deaths']*(1/(usa['Death_rate'] + 0.0000001) - 1)

# %%
def plot_geo(colname, continent=None):
    
    
    data = prepare_geo()
    
    data = data[data.Country!="Antarctica"]

    if continent:
        data = data[data.Continent == continent] 

    fig, ax = plt.subplots(1, 1, figsize=(16, 12))
    
    
    if not continent:
        #ax.set(xlim=(-24, 40), ylim=(35, 75))
        fontsize = 6
    elif continent == 'Europe':
        ax.set(xlim=(-24, 40), ylim=(35, 75))
        fontsize = 8
        ax.text(1, 46, 'France', fontsize=fontsize)
        ax.text(8, 62, 'Norway', fontsize=fontsize)
        
    elif continent == 'America':
        ax.set(xlim=(-130, -30), ylim=(-55, 75))
        fontsize = 10     
        ax.text(-103, 38, 'USA', fontsize=fontsize)    
        ax.text(-107, 53, 'Canada', fontsize=fontsize)
    elif continent == 'Asia':
        ax.set(xlim=(20, 145), ylim=(-10, 75))
        fontsize = 8     
    else:
        fontsize = 8

    

    data.plot(column=colname, ax=ax, legend=True, cmap='Wistia', legend_kwds={'label': "{}".format(colname), 
                                                                      'orientation': "vertical"})

    plt.xlabel("Longitude")
    plt.ylabel("Latitude")
    #plt.xticks([10.7, 10.8, 10.9])
    #plt.yticks([59.8, 59.9, 60.0])
    #plt.suptitle('Marka', y=0.73, fontsize=10)

    plt.title('{}: {}\n'.format(continent, colname),  fontsize=18)
    
    #plt.axis('off')

    skip_list = ['Norway', 'France', 'United States of America', 'Canada']

    for idx, row in data.iterrows():
        
        if (len(str(row['Country'])) > 3) & (str(row['Country']) not in skip_list):
            plt.annotate(s=row['Country'], xy=row['geometry'].centroid.coords[0],
                     horizontalalignment='center', fontsize=fontsize)

# %%
plot_geo(colname = 'Infected_percent', continent = 'Europe')

# %%
plot_geo(colname = 'Recovered_per_100k', continent = 'Europe')

# %%
plot_geo(colname = 'Deaths_per_100k', continent = 'Europe')

# %%
plot_geo(colname = 'Infected_per_100k', continent = 'Asia')

# %%
plot_geo(colname = 'Infected_per_100k', continent = 'America')

# %%
plot_geo(colname = 'Infected_per_100k', continent = 'Africa')

# %%
dfx = prepare_geo()
fig = px.choropleth(dfx, locations="Short",
                    color="Infected_per_100k", # lifeExp is a column of gapminder
                    hover_name="Country", # column to add to hover information
                    color_continuous_scale=px.colors.sequential.Plasma)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-87-9d45719fef98> in <module>
#       1 dfx = prepare_geo()
# ----> 2 fig = px.choropleth(dfx, locations="Short",
#       3                     color="Infected_per_100k", # lifeExp is a column of gapminder
#       4                     hover_name="Country", # column to add to hover information
#       5                     color_continuous_scale=px.colors.sequential.Plasma)
#
# NameError: name 'px' is not defined

# %%
dfx

# %%
dfx = dfx.fillna(0)

# %%
dfx = dfx[['Country', 'Short', 'Infected_per_100k']]

# %%
dfx.sort_values('Infected_per_100k', ascending=False, inplace=True)

# %%
countrylist = dfx.Country.unique().tolist()

# %%
countrylist

# %%
x_val = dfx[dfx['Country'] == 'Luxembourg'].Infected_per_100k.tolist()
x_val
