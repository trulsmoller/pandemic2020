# %% [markdown]
# ### Capstone Project:
#
# # 2020 Pandemic and the Curious Case of Sweden
#
# #### By Truls Møller 2020-07-07

# %% [markdown]
# ![sweden_supporters.jpg](attachment:sweden_supporters.jpg)

# %% [markdown]
# ### Table of Contents
#
# * [Introduction](#chapter1)
#     * [Background](#section_1_1)
#     * [Understanding of COVID-19 Virus](section_1_2)
# * [Project Definition](#chapter2)
#     * [Project Overview](#section_2_1)
#     * [The Data](#section_2_2)
#     * [Project Statement](#section_2_3)
#     * [Metrics](#section_2_4)
# * [Data Wrangling](#chapter3)
#     * [Update Data](#section_3_1)
#     * [Clean Data](#section_3_2)
#     * [Add Metrics](#section_3_3)
#     * [Filter Data](#section_3_4)
#     * [Final Preprosessing for Plotly](#section_3_5)
# * [Exploratory Analysis](#chapter4)
#     * [Current Data](#section_4_1)
#     * [Historic Daily Data](#section_4_2)
#     * [Historic Weekly Data](#section_4_3)
# * [Results](#chapter5)
# * [Conclusion](#chapter6)
# * [Improvement](#chapter7)

# %% [markdown]
# ### Introduction <a class="anchor" id="chapter1"></a>

# %% [markdown]
# In the midst of crisis I seek to understand the nature of the decease &mdash; and the consequences of our response.
#
# I will start with a global view, and then I will zoom in on Sweden.
#
# Sweden stands out because they have not applied the common lockdown strategy. Instead, businesses and schools have been kept open. To a large degree it has been business as usual for the Swedish population.
#
# I live "next door" in Norway, where lockdown has been strict and sosial distancing has been practiced, and it will be interesting to look into the consequences for Sweden and even project into the future!
#
# I will give you `deaths` statistics.
#
# I will give you estimates of the `Infection rate (R)`.
#
# And it will be displayed in a web app that can easily be maintained.
#
# The results will let me answer some fundamental questions of mine, filed under the chapter 'Business Questions'.

# %% [markdown]
# #### Background   <a class="anchor" id="section_1_1"></a>

# %% [markdown]
# It started in Wuhan, China. Of the first 425 confirmed cases, the majority (55%) with onset before January 1, 2020, were linked to the Huanan Seafood Wholesale Market. The mean incubation period was 5.2 days. In its early stages, the epidemic doubled in size every 7.4 days.
#
#
#
# Everyone hoped that the virus would be stopped, even though there were a few cases outside China. On the 11th of March, however, WHO made the assessment that COVID-19 could be characterized as a pandemic.
# https://www.who.int/news-room/detail/29-06-2020-covidtimeline
#
# **You can't spell pandemic without panic!**  - ie. a sudden sensation of fear. And that was the common experience for people all over the world when the graveness of the situation became known. Could it be as deadly as the Spanish Flu of 1918, which killed around 1 percent of the world population? Could it be worse?
#
# Attempts were made by governments, health orginizations, universities, statisticians, data analysts, data scientists etc. to understand how the virus behaved. Not all models were great. It was a big challenge. What data could be trusted?

# %% [markdown]
# #### Understanding of COVID-19 Virus  <a class="anchor" id="section_1_2"></a>
#
# Here is a Q & A on the current understanding how the virus "works". It will also highlight some of the complexity.
#
#     1. How many get infected by the virus but has no (serious) symptoms?
#
# Answer: The dark numbers is a big issue. It's good if they are large. Then the true mortality rate is lower, and we would reach herd immunity sooner, which again would lower the infection rate (R). It's still a challenge that we do not know the dark numbers, and they will vary a lot from country to country depending on how many people are tested.
#
#     2. Would those be immune who already had it and recovered from it?
#
# Answer: Most likely. Repeat cases have not been documented at this point (that would be major news!). However, it is too soon to tell if immunity could be lost over time.
#
#     3. Viruses are known to mutate. Will COVID-19 get stronger or milder over time?
#
# Answer: The virus is mutating, but very slowly, and the copies are not far from the original virus. This type of virus (RNA) is more likely to mutate into a weaker version. Overall that's a good thing. However, when such viruses get weaker, they tend to transfer more easily, which again would increase the infection rate (R). Source:
# [healthline.com](https://www.healthline.com/health-news/what-to-know-about-mutation-and-covid-19)

# %% [markdown]
# ### Project Definition <a class="anchor" id="chapter2"></a>

# %% [markdown]
# #### Project Overview  <a class="anchor" id="section_2_1"></a>
#
# The origin of the project were two things:
#
#     1. My frustration over lack of death numbers in the media to provide a good picture of the situation
#     2. Compassion with my neighbor country of Sweden, where there has not been any degree of lockdown,
#        and now the death toll is more than 10x of my own country Norway.
#
# It seems important to get a sober picture and look into the data myself, and even learn some things about this aspect of the healthcare domain.
#
# The data will be the widely used dataset compiled by John Hopkins University. We will be downloading the data from a Kaggle user who has shared it there, but it comes from John Hopkins University.

# %% [markdown]
# #### The Data  <a class="anchor" id="section_2_2"></a>

# %% [markdown]
# Sources for datasets:
#
# Updated through this notebook:
# - covid-19 related datasets will be connected to this Kaggle user Sudalairaj Kumar, it originates from John Hopkins University.: https://www.kaggle.com/sudalairajkumar/novel-corona-virus-2019-dataset/discussion/136061
#
# Downloaded once:
# - population_by_country: https://www.kaggle.com/tanuprabhu/population-by-country-2020
#     I have manually added some ISO country codes, changed country names to fit with the corresponding country names used in the covid-19 dataset and stored it in the data folder as 'population_2020_for_johnhopkins_data.csv'
# - natural earth polygon shapes of countries: https://www.naturalearthdata.com/downloads/10m-cultural-vectors/10m-admin-0-countries/

# %% [markdown]
# #### Problem Statement  <a class="anchor" id="section_2_3"></a>
#
#     1. What is the current global picture of how many lives have been lost to the COVID-19 virus?
#
#     2. Looking at the top 10 countries based on highest number of deaths relative to population, how has the development been over time?
#
#     3. How is Sweden's R value developing, and how does it compare to its neighboring countries?
#
#     4. What scenarios lie ahead for Sweden?

# %% [markdown]
# My strategy will be to do most of the exploring in this **Jupyter Notebook**. The **Pandas** library will be key and I'll add other libraries whenever I need them. Then the some of the key visualizations will be deployed to a web app hosted on **Heroku**. I will get the web app up and running quickly and add content when it feels ready. I will not use any machine learning for this project. The challenges for me will be the data engineering part, the software engineering part, working with time series data and working with a real live scenario where new date becomes available daily.
#
# The order of things will look like this:
#
#     - Set up local and Github repo
#     - Add readme file
#     - Gather data compiled by John Hopkins University. Automate a way updating on a daily basis.
#     - Gather data on country level: Population, ISO-codes etc. Static data on file will do.
#     - Clean and merge data into a Pandas DataFrame
#     - Prepare data for visualizations that will help answer business questions
#     - Deploy first content to web app
#     - Explore data, decide metrics
#     - Conclusions to business questions
#     - Finalize web app
#     - Some discussion on possible future improvements
#     - Finalize readme file

# %% [markdown]
# #### Metrics    <a class="anchor" id="section_2_4"></a>
#
# In order to address the business questions I will need to look at total deaths and daily deaths, preferably in relative terms, ie. compared to the population.
#
# Assumptions and comments given below each metric.
#
#
#     1. 'Population'
#
#     Assumption: Population numbers are nearly static in the course of a few months
#
#     Comment: It's not perfect to use static numbers for population. However, it shouldn't be an issue over a few months. If the tracking is extended to last for years, it would be wise to update the population numbers, of course.
#
#     2. 'Total_deaths'
#     3. 'Total_deaths_per_100k' (derived from 'Total_deaths' and 'Population')
#     4. 'Deaths'                (derived from 'Total_deaths', means new daily)
#     5. 'Deaths_per_100k'       (derived from 'Deaths' and 'Population')
#     6. 'Deaths_s7'             (derived from 'Deaths')
#     7. 'Deaths_per_100k_s7'    (derived from 'Deaths_per_100k')
#     8. 'Deaths_week'           (derived from 'Deaths', means sum of new daily for the past 7 days)
#     9. 'Deaths_lastweek'       (derived from 'Deaths', means sum of new daily for the past 14-8 days)
#
#     Assumption: Reported numbers on 'Total_deaths' are accurate
#
#     Comment: Again it's not a perfect assumption, as there are different practices in different countries on determining the cause of death. For instance, if someone who is confirmed to be infected dies of heart failure, it could be labeled as 'heart failure' even though the underlying reason was the corona virus. There are also countries not all of the population are registered as citizens; they are outside the system. However, mostly, the count of deaths is trustworthy and it will give a very good indication of the true number of casualities due to the virus.
#
#     10. 'Infection_rate'       (derived from 'Deaths_week' and 'Deaths_lastweek')
#
#     Assumption: R can be estimated from the ratio week-over-week deaths:
#
#                R = Deaths_week_n/Deaths_week_n_minus_1
#
#            This again is based on the assumption that a fixed ratio of the truly infected dies.
#            And the assumption that a typical tranfer rate from one human to the next of seven days.
#
#     Comment: My first idea to calculate infection rate R was the more natural* choice, namely to take
#
#             Infected_week_n/Infected_week_n_minus_1.
#
#         *Natural, because the true infection number, if we knew it, would yield the true R.
#         However, since infected number are less trustworthy than the death numbers and more liable to vary from
#         country to country, I decided the chosen estimation method of R is much better.
#
#         This is also based on incubation time, and using weekly sums, there will be a smoothing effect, which
#         should reduce some noise in the trend curve (weekly seasonality).

# %% [markdown]
# ### Data Wrangling <a class="anchor" id="chapter3"></a>

# %%
import os
import zipfile
import datetime as dt
from datetime import timedelta

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt


import geopandas as gpd
import descartes

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline
pd.set_option('display.max_columns', 50)
pd.set_option('display.max_rows', 200)

# %% [markdown]
# We will download covid-19 data programmatically. Currently there are updates on a daily basis.
#
# We will follow these steps:
#
# - Rename current file `data/covid_19_data.csv` by adding a `yymmdd` date extension to the file name and thereby, in effect, archiving it.
# - Download new file. Currently it comes compressed as a zip file, hence our target file is extracted and the zip file gets deleted.

# %%
# Setting file name and path of data files

# 1) The covid_19 data file

DATA_FOLDER_PATH = os.path.join(os.path.curdir, 'data')
DATA_NAME = 'covid_19_data.csv'
DATA_PATH = os.path.join(DATA_FOLDER_PATH, DATA_NAME)

# 2) The population data file

POPDATA_NAME = 'population_2020_for_johnhopkins_data.csv'
POPDATA_PATH = os.path.join(DATA_FOLDER_PATH, POPDATA_NAME)

# Making sure we have the correct path to the data. 
# This should be the case if this notebook was opened 
# in the root directory of the web app

required_data_path = './data/covid_19_data.csv'
required_popdata_path = './data/population_2020_for_johnhopkins_data.csv'

assert DATA_PATH == required_data_path, 'Error: Working directory must be the root directory of the web app'
print('Great. The path is correct for the covid-19 data.')
assert POPDATA_PATH == required_popdata_path, 'Error: Working directory must be the root directory of the web app'

print('Great. The path is correct for the population data.')
# Out:
# Great. The path is correct for the covid-19 data.
# Great. The path is correct for the population data.

# %% [markdown]
# Next we create three functions, that we will help us in the chore of updating the covid-19 data.

# %%
def archive_data(file_name, file_path):
    '''
    This function archives the old data file by renaming it with a date suffix in the format yymmdd,
    and then it prints a confirmation that the old data was archived including the name of the archived file
    
    Args:
        file_name (str): name of covid-19 data file
        file_path (str): path to covid-19 data file

    Returns:
        this function does not return anything
    '''

    file_full_path = os.path.join(file_path, file_name)

    try:
        mtime = os.path.getmtime(file_full_path)
        last_modified_time = dt.datetime.fromtimestamp(mtime) 
        last_data_date = last_modified_time - timedelta(days=1)
        date_extention = str(last_data_date.year)[2:].zfill(2) + str(last_data_date.month).zfill(2) + str(last_data_date.day).zfill(2)
        new_file_name = file_name[:-4] + date_extention + file_name[-4:]
        new_file_full_path = os.path.join(file_path, new_file_name)
        os.rename(file_full_path, new_file_full_path)
        print("- Old data file archived as: '{}'".format(new_file_name))
        print()
    except OSError:
        mtime = 0

# %%
def download_data(file_name, file_path):
    '''
    This function programmatically downloads the new data file from kaggle to the 'data' folder
    in the root directory of the web app. The new data file is compressed into .zip format
    
    Args:
        file_name (str): name of covid-19 data file
        file_path (str): path to covid-19 data file

    Returns:
        this function does not return anything
    '''
    
    # !kaggle datasets download -d sudalairajkumar/novel-corona-virus-2019-dataset -f $file_name -p $file_path --force

# %%
def extract_zip_file(file_name, file_path):
    '''
    This function unzips the compressed new data file found in the 'data' folder
    in the root directory of the web app. Then the zip file is deleted.
    
    Args:
        file_name (str): name of covid-19 data file
        file_path (str): path to covid-19 data file

    Returns:
        this function does not return anything
    '''
    
    for i,file in enumerate(os.listdir(file_path)):
        # looping through the files in the data folder, we search for the one ending with ".zip"
        if file.endswith(".zip"):
            try:
                # we obtain the zip file name, its full path and unzip it in the same folder
                zip_file_name = os.path.basename(file)
                zip_full_path = os.path.join(file_path, zip_file_name)
                
                with zipfile.ZipFile(zip_full_path, 'r') as zip_ref:
                    zip_ref.extractall(file_path)
                
                print()
                print("- New file extracted from compressed file to data folder as: '{}'".format(file_name))
                print()
                os.remove(zip_full_path)
                print('- Zip file deleted post extraction.')
            except OSError:
                pass

# %% [markdown]
# We utilize the above three functions in our main function for updating the covid-19 data: `get_latest_data()`

# %%
def get_latest_data(file_name, file_path):
    
    '''
    This function is our main function for updating the covid-10 data. It will utilize our
    three helper functions 'archive_data()', 'download_data()' and 'extract_zipfile()' for completing 
    a sequence of tasks:
    
    - Rename current file data/covid_19_data.csv by adding a yymmdd date extension to the file name 
    and thereby, in effect, archiving it.
    - Download new file, which is compressed into .zip format
    - Extract data file 'covid_19_data.csv' from zip-file
    - Delete zip-file
    
    For each task in the sequence a confirmation is printed.
    Finally, a confirmation is printed once the full sequence is successfully completed: 
    'COMPLETED sequence for updating data successfully!'
    
    Args:
        file_name (str): name of covid-19 data file
        file_path (str): path to covid-19 data file

    Returns:
        this function does not return anything
    '''
    
    file_full_path = os.path.join(file_path, file_name)

    try:
        # get the time of last modification of the specified path; the getmtime method returns 
        # a floating point value which represents the number of seconds since the epoch. 
        # This method raise OSError if the file does not exist or is somehow inaccessible.
        mtime = os.path.getmtime(file_full_path)
        
        # converting floating point value to a datetime date
        last_modified_date = dt.datetime.fromtimestamp(mtime).date()
        
        # compare last_modified_date of current file with today's date and only initiate sequence 
        # if the current data file is indeed old, ie. it was last modified yesterday or earlier
        today_date = dt.date.today()
        
        if last_modified_date == today_date:
            print("We already have the latest data")
            
        elif last_modified_date < today_date:
            print('STARTING sequence for updating data...')
            print()
            
            archive_data(file_name, file_path)
            
            download_data(file_name, file_path)
            
            extract_zip_file(file_name, file_path)
            
            print()
            print('COMPLETED sequence for updating data successfully!')
        else:
            print('Error: Not able to comprehend; last_modified_date set to the future')
        
    except OSError:
        print('Error: Not able to extract meta data for provided file_name/file_path')

# %% [markdown]
# #### Update Data <a class="anchor" id="section_3_1"></a>

# %% [markdown]
# Running the below cell initiates the sequence of updating the covid-19 data:

# %%
# update data
get_latest_data(DATA_NAME, DATA_FOLDER_PATH)
# Out:
# STARTING sequence for updating data...
#
# - Old data file archived as: 'covid_19_data201018.csv'
#
# ...
# 100%|██████████████████████████████████████| 1.90M/1.90M [00:00<00:00, 5.58MB/s]
# 100%|██████████████████████████████████████| 1.90M/1.90M [00:00<00:00, 6.08MB/s]
#
# - New file extracted from compressed file to data folder as: 'covid_19_data.csv'
#
# - Zip file deleted post extraction.
#
# COMPLETED sequence for updating data successfully!

# %% [markdown]
# #### Clean Data <a class="anchor" id="section_3_2"></a>

# %% [markdown]
# The next two functions are simply for reading our csv files. One with population data and one with covid-19 data.

# %%
def get_popdata(popdata_path = POPDATA_PATH):
    '''
    This function reads the population data from csv file into a pandas DataFrame, cleans up the
    column names and transforms 'Urban population ratio' data to type Float. 
    
    The data contains the following on country-level:
    
    - Country name
    - ISO code as described in the ISO 3166 international standard, the 3-letter version ('Short') 
    - Continent
    - Population
    - Population per square kilometer
    - Median age
    - Urban population ratio
    
    Args
        popdata_path (str): path to the population data file

    Returns:
        df_pop (dataframe): population dataframe
    '''
    
    # population dataset read into dataframe
    df_pop = pd.read_csv(popdata_path, delimiter=";") 
    
    # setting column headers
    df_pop.columns = ['Country', 'ISO', 'Continent', 'Population', 'Pop_km2', 'Median_age', 'Urban_Population_percent']
    
    # extracting the ratio from string column 'UrbanPopPercent' and replacing it with a new column with
    # float values for ratio.
    df_pop['Urban_Population_ratio'] = df_pop['Urban_Population_percent'].str.strip('%').astype(float).div(100)
    df_pop.drop('Urban_Population_percent', axis = 1, inplace=True)
    
    return df_pop

# %%
def get_covid_data(data_path = DATA_PATH):
    '''
    This function reads the covid-19 data from csv file into a pandas DataFrame, cleans up the
    column names and updates some of the country names to match the ones used in the population dataset. 
    
    The data contains the following on country-level:
    - Country name
    - Date (Daily. The start date is not the same for all countries; it ranges from January to March 2020)
    - Deaths (total number for respective country at respective date)
    
    Args:
        data_path (str): path to covid-19 data file

    Returns:
        this function does not return anything
    '''
    
    df = pd.read_csv(data_path) # population dataset read into dataframe
    
    # clean data
    
    df = df.rename(columns={"ObservationDate": "Date", "Country/Region": "Country"})
    
    df = df.groupby(['Country', 'Date']).sum().reset_index()
    
    # update some of the country names to match the ones used in the population dataset
    
    df['Country'] = df['Country'].replace({'UK': 'United Kingdom', 
                                           'US': 'United States', 
                                           'Mainland China': 'China',
                                           'Czech Republic': 'Czechia',
                                           'Burma': 'Myanmar'
                                           })
    try:
        df['Country'] = df['Country'].replace({"('St. Martin',)": "St. Martin",
                                               "occupied Palestinian territory": "Palestine",
                                               "State of Palestine": "Palestine",
                                               "Ivory Coast": "Cote d'Ivoire",
                                               "Gambia, The": "Gambia",
                                               "The Gambia": "Gambia",
                                               "The Bahamas": "Bahamas",
                                               "Bahamas, The": "Bahamas",
                                               "Republic of Ireland": "Ireland",
                                               "Republic of the Congo": "Congo (Brazzaville)",
                                               " Azerbaijan": "Azerbaijan"
                                              
                                              })
    except:
        pass
        
    # sort on Country, then Date. Mostly it is only one row getting grouped, whereever data is on regional
    # groupby ensures we get the data summed up to country level
    df_covid = df.groupby(['Country', 'Date']).sum().reset_index()
    
    # dropping columns we will not use.
    df_covid.drop(['SNo', 'Confirmed', 'Recovered'], axis=1, inplace=True)
    
    df_covid.columns = ['Country', 'Date', 'Total_deaths']
    
    return df_covid

# %%
# quick test function for getting population data
df_pop = get_popdata()
df_pop.head()
# Out:
#        Country  ISO Continent  Population  Pop_km2  Median_age  \
# 0  Afghanistan  AFG      Asia    38928346       60          18
# 1      Albania  ALB    Europe     2877797      105          36
# 2      Algeria  DZA    Africa    43851044       18          29
# 3       Angola  AGO    Africa    32866272       26          17
# 4    Argentina  ARG   America    45195774       17          32
#
#    Urban_Population_ratio
# 0                    0.25
# 1                    0.63
# 2                    0.73
# 3                    0.67
# 4                    0.93

# %%
# quick test function for getting covid-19 data
df_covid = get_covid_data()
df_covid.head()
# Out:
#        Country        Date  Total_deaths
# 0  Afghanistan  02/24/2020           0.0
# 1  Afghanistan  02/25/2020           0.0
# 2  Afghanistan  02/26/2020           0.0
# 3  Afghanistan  02/27/2020           0.0
# 4  Afghanistan  02/28/2020           0.0

# %%
# Countries not found in df_covid, assumed as 'not reporting'
s1 = df_pop.Country
s2 = df_covid.Country

s1[~s1.isin(s2)].reset_index(drop=True).squeeze()
# Out:
# 0     North Korea
# 1    Turkmenistan
# Name: Country, dtype: object

# %%
# Countries not available in df_pop (micro states, low population states, no population data etc.)
# I am leaving these out, as it would require too much manual work.

s2[~s2.isin(s1)].to_frame().groupby('Country').count().reset_index().squeeze()
# Out:
# 0                              Andorra
# 1                  Antigua and Barbuda
# 2                                Aruba
# 3                              Bahamas
# 4                              Bahrain
# 5                             Barbados
# 6                               Belize
# 7                               Bhutan
# 8                               Brunei
# 9                           Cabo Verde
# 10                          Cape Verde
# 11                      Cayman Islands
# 12                     Channel Islands
# 13                             Comoros
# 14                             Curacao
# 15                    Diamond Princess
# 16                            Djibouti
# 17                            Dominica
# 18                          East Timor
# 19                   Equatorial Guinea
# 20                            Eswatini
# 21                       Faroe Islands
# 22                                Fiji
# 23                       French Guiana
# ...

# %%
def merge_data():
    '''
    This function gets the population data and the covid-19 data and merges them to one dataframe
    
    Args:
        None

    Returns:
        df_merged (dataframe): merged data
    '''
    
    df_pop = get_popdata()
    
    df_covid = get_covid_data()
    
    df_merged = df_covid.set_index('Country').join(df_pop.set_index('Country')).reset_index()
    
    df_merged.dropna(subset=['Population'], inplace=True)

    
    
    df_merged = df_merged[['Date', 'Continent', 'Country', 'ISO', 'Population', 'Urban_Population_ratio', 'Pop_km2', 'Median_age', 'Total_deaths']]
    
    df_merged.Date = pd.to_datetime(df_merged.Date, infer_datetime_format=True)
    
    return df_merged

# %%
df_merged = merge_data()
df_merged.head()
# Out:
#         Date Continent      Country  ISO  Population  Urban_Population_ratio  \
# 0 2020-02-24      Asia  Afghanistan  AFG  38928346.0                    0.25
# 1 2020-02-25      Asia  Afghanistan  AFG  38928346.0                    0.25
# 2 2020-02-26      Asia  Afghanistan  AFG  38928346.0                    0.25
# 3 2020-02-27      Asia  Afghanistan  AFG  38928346.0                    0.25
# 4 2020-02-28      Asia  Afghanistan  AFG  38928346.0                    0.25
#
#    Pop_km2  Median_age  Total_deaths
# 0     60.0        18.0           0.0
# 1     60.0        18.0           0.0
# 2     60.0        18.0           0.0
# 3     60.0        18.0           0.0
# 4     60.0        18.0           0.0

# %% [markdown]
# #### Add Metrics <a class="anchor" id="section_3_3"></a>

# %% [markdown]
# We need to do a little feature engineering to get meaningful metrics.

# %%
def add_calculated_cols(df_merged):
    '''
    This function adds some calculated columns to the dataframe:
        - Deaths (daily deaths)
        - Deaths_s7 (Deaths smoothed with a seven day moving average)
        - Deaths_per_100k_s7 (Relative version of Deaths_s7)
        - Year_week (Year and week number combined, format: yyyy-ww)
        - Deaths_week (Deaths during Year_week - sum of deaths during a seven day period)
        - Deaths_lastweek (Sum of deaths during the preceding seven day period)
        - Infecton_rate (Deaths_week divided by Deaths_lastweek, equal to 1.0 if the death count
                        was the same in those two consequent weeks)

    Args:
        df_merged (dataframe): df containing covid-19 data as well as population data

    Returns:
        df_full (dataframe): Input df modified; with new calculated columns added
    '''
    
    df = df_merged.copy()
    
    df['Total_deaths_per_100k'] = 100000*df['Total_deaths']/(df['Population'] + 1.0)
    
    df['Weekday'] = df['Date'].dt.weekday
    
    df['Year_week'] = df['Date'].dt.strftime('%G-%V')
    
    country_codes = df.ISO.unique().tolist()
    
    country_dfs = []
    
    for code in country_codes:
        
        notgrouped = df[df['ISO'] == code]
        notgrouped.set_index('Year_week')
        notgrouped['Total_deaths_yesterday'] = notgrouped['Total_deaths'].shift(1).fillna(0)
        notgrouped['Deaths'] = notgrouped['Total_deaths'] - notgrouped['Total_deaths_yesterday']
        notgrouped['Shift1'] = notgrouped['Deaths'].shift(1).fillna(0)
        notgrouped['Shift2'] = notgrouped['Deaths'].shift(2).fillna(0)
        notgrouped['Shift3'] = notgrouped['Deaths'].shift(3).fillna(0)
        notgrouped['Shift4'] = notgrouped['Deaths'].shift(4).fillna(0)
        notgrouped['Shift5'] = notgrouped['Deaths'].shift(5).fillna(0)
        notgrouped['Shift6'] = notgrouped['Deaths'].shift(6).fillna(0)
        notgrouped['Deaths_s7'] = ((notgrouped['Deaths'] + notgrouped['Shift1'] + notgrouped['Shift2'] + \
                                  notgrouped['Shift3'] + notgrouped['Shift4'] + notgrouped['Shift5'] + \
                                  notgrouped['Shift6'])/7.0).astype(int)
        notgrouped['Deaths_per_100k_s7'] = 100000*notgrouped['Deaths_s7']/(notgrouped['Population'] + 1.0)
        
        notgrouped.drop(['Total_deaths_yesterday', 'Shift1', 'Shift2', 'Shift3', 'Shift4', 'Shift5', 'Shift6'], axis=1, inplace=True)
        notgrouped.set_index('Year_week', inplace=True)

        grouped = notgrouped.groupby(['Year_week']).sum()
        grouped.rename(columns={"Deaths": "Deaths_week"}, inplace=True)
        grouped['Deaths_lastweek'] = grouped['Deaths_week'].shift(1).fillna(0)
        grouped['Infection_rate'] =  (grouped['Deaths_week'] / grouped['Deaths_lastweek']).fillna(0).replace(np.inf, 0)
        grouped = grouped[['Deaths_week', 'Deaths_lastweek', 'Infection_rate']]

        regrouped = notgrouped.join(grouped)
        
        #regrouped.rename(columns={"Deaths": "Deaths_week"}, inplace=True)
        
        country_dfs.append(regrouped)
        
    df_full = pd.concat(country_dfs)
    
    df_full['Deaths_per_100k'] = 100000*df_full['Deaths']/(df_full['Population'] + 1.0)
    df_full['Deaths_week_per_100k'] = 100000*df_full['Deaths_week']/(df_full['Population'] + 1.0)
    
    df_full.reset_index(inplace=True)
    
    return df_full

# %%
# quick test to confirm new columns get added
df_full = add_calculated_cols(df_merged)
df_full
# Out:
#       Year_week       Date Continent      Country  ISO  Population  \
# 0       2020-09 2020-02-24      Asia  Afghanistan  AFG  38928346.0
# 1       2020-09 2020-02-25      Asia  Afghanistan  AFG  38928346.0
# 2       2020-09 2020-02-26      Asia  Afghanistan  AFG  38928346.0
# 3       2020-09 2020-02-27      Asia  Afghanistan  AFG  38928346.0
# 4       2020-09 2020-02-28      Asia  Afghanistan  AFG  38928346.0
# ...         ...        ...       ...          ...  ...         ...
# 31208   2020-38 2020-09-19    Africa     Zimbabwe  ZWE  14862924.0
# 31209   2020-38 2020-09-20    Africa     Zimbabwe  ZWE  14862924.0
# 31210   2020-39 2020-09-21    Africa     Zimbabwe  ZWE  14862924.0
# 31211   2020-39 2020-09-22    Africa     Zimbabwe  ZWE  14862924.0
# 31212   2020-39 2020-09-23    Africa     Zimbabwe  ZWE  14862924.0
#
#        Urban_Population_ratio  Pop_km2  Median_age  Total_deaths  \
# 0                        0.25     60.0        18.0           0.0
# ...

# %% [markdown]
# #### Filter Data <a class="anchor" id="section_3_4"></a>

# %% [markdown]
# We need to be able to get historic data for time series analysis and current data for current status overview. These are the main filtering options. In addition, we will need to get historic data aggregated weekly, in order to look at week over week changes, from which we can estimate the infection rate R.

# %%
def dates_choice(df, all_dates=False, weekly=False):
    '''
    This function selects dates based on input. There are three types
    
    1. Historic daily data (all_dates=True)
    2. Historic weekly data (weekly=True, all_dates=False)
    3. Latest date data (weekly=False, all_dates=False)
    
    The historic data will be suitable for performing time series analysis.
    
    The latest date data will be suitable to look at the overall picture (such as accumulated death 
    count per country).
    
    Args:
        df (dataframe): df containing covid-19 data as well as population data
        
        all_dates (boolean): Optional argument - True if you wish to get daily historic data
        
        weekly (boolean): Optional argument - True if you wish to get historic weekly data

    Returns:
        df (dataframe): Based on choices
    '''    
    
    if all_dates:
        
        # No filtering required since all_dates is requested
        
        pass
    
    else:
        
        if weekly:
            
            # we wish to filter on Sundays because that is always the last day of each 'Year_week' 
            # (for instance last day of week 20, 21, 22 etc. is always a Sunday). However, due to the
            # fact that earlier applied function 'add_calculated_cols' does a simple groupby('Year_week')
            # to obtain the aggregated weekly numbers, the first aggregation for each country will often 
            # be based on less than seven days. So before filtering we will change the value of those cases
            
            for i in range(df.shape[0]):
                
                # looping dataframe, which is sorted by country then date
                
                # check if the current row is the first of a new country
                
                if i == 0:
                    
                    new_country = True
                    
                else:
                    
                    if df.ISO[i] == df.ISO[i-1]:
                        
                        new_country = False
                        
                    else:
                        
                        new_country = True
                
                # if it is we find the row of the first '6', which could be on the current row
                # or any of the next six rows.
                # We change its value unless the weekday is '0' (in which case the first '6' will 
                # be the seventh element, and we do not have to change its value)
                
                if new_country:
                    
                    wd = df.Weekday[i]
                    
                    if wd > 0:
                        
                        diff = 6 - wd
                        df.Weekday[i + diff] = 0
            
            # Finally we filter the dataframe on Sundays
            
            df = df[df.Weekday == 6]
            
        else:
            
            # In this case we have neither asked for all dates nor weekly dates,
            # which means we will get the last date only.
            
            df = df[df.Date == df.Date.max()].reset_index(drop=True)
            
            
    # we set the dates as index and make sure it is in datetime format    
        
    df = df.reset_index(drop=True).set_index('Date')
    df.index = pd.to_datetime(df.index, infer_datetime_format=True)
            
    return df

# %%
# quick test 1): Historic daily data
df_historic = dates_choice(df_full, all_dates=True, weekly=False)
df_historic.head(3)
# Out:
#            Year_week Continent      Country  ISO  Population  \
# Date
# 2020-02-24   2020-09      Asia  Afghanistan  AFG  38928346.0
# 2020-02-25   2020-09      Asia  Afghanistan  AFG  38928346.0
# 2020-02-26   2020-09      Asia  Afghanistan  AFG  38928346.0
#
#             Urban_Population_ratio  Pop_km2  Median_age  Total_deaths  \
# Date
# 2020-02-24                    0.25     60.0        18.0           0.0
# 2020-02-25                    0.25     60.0        18.0           0.0
# 2020-02-26                    0.25     60.0        18.0           0.0
#
#             Total_deaths_per_100k  Weekday  Deaths  Deaths_s7  \
# Date
# 2020-02-24                    0.0        0     0.0          0
# 2020-02-25                    0.0        1     0.0          0
# 2020-02-26                    0.0        2     0.0          0
#
#             Deaths_per_100k_s7  Deaths_week  Deaths_lastweek  Infection_rate  \
# Date
# 2020-02-24                 0.0          0.0              0.0             0.0
# ...

# %%
# quick test 2): Historic weekly data
df_weekly = dates_choice(df_full, all_dates=False, weekly=True)
df_weekly.head(3)
# Out:
#            Year_week Continent      Country  ISO  Population  \
# Date
# 2020-03-01   2020-09      Asia  Afghanistan  AFG  38928346.0
# 2020-03-08   2020-10      Asia  Afghanistan  AFG  38928346.0
# 2020-03-15   2020-11      Asia  Afghanistan  AFG  38928346.0
#
#             Urban_Population_ratio  Pop_km2  Median_age  Total_deaths  \
# Date
# 2020-03-01                    0.25     60.0        18.0           0.0
# 2020-03-08                    0.25     60.0        18.0           0.0
# 2020-03-15                    0.25     60.0        18.0           0.0
#
#             Total_deaths_per_100k  Weekday  Deaths  Deaths_s7  \
# Date
# 2020-03-01                    0.0        6     0.0          0
# 2020-03-08                    0.0        6     0.0          0
# 2020-03-15                    0.0        6     0.0          0
#
#             Deaths_per_100k_s7  Deaths_week  Deaths_lastweek  Infection_rate  \
# Date
# 2020-03-01                 0.0          0.0              0.0             0.0
# ...

# %%
# quick test 3): Latest date data
df_current = dates_choice(df_full, all_dates=False, weekly=False)
df_current.head(3)
# Out:
#            Year_week Continent      Country  ISO  Population  \
# Date
# 2020-09-23   2020-39      Asia  Afghanistan  AFG  38928346.0
# 2020-09-23   2020-39    Europe      Albania  ALB   2877797.0
# 2020-09-23   2020-39    Africa      Algeria  DZA  43851044.0
#
#             Urban_Population_ratio  Pop_km2  Median_age  Total_deaths  \
# Date
# 2020-09-23                    0.25     60.0        18.0        1446.0
# 2020-09-23                    0.63    105.0        36.0         370.0
# 2020-09-23                    0.73     18.0        29.0        1698.0
#
#             Total_deaths_per_100k  Weekday  Deaths  Deaths_s7  \
# Date
# 2020-09-23               3.714517        2     1.0          1
# 2020-09-23              12.857053        2     3.0          3
# 2020-09-23               3.872200        2     9.0          7
#
#             Deaths_per_100k_s7  Deaths_week  Deaths_lastweek  Infection_rate  \
# Date
# 2020-09-23            0.002569          5.0             21.0        0.238095
# ...

# %% [markdown]
# #### Final Preprocessing for Plotly <a class="anchor" id="section_3_5"></a>

# %%
def select_continent(df, continent):
    '''
    This function filters the dataframe on a single continent
    
    Args:
        df (dataframe): Dataset including a column 'Continent'
        continent (string): Name of continent. Valid values are found in below list

    Returns:
        df_continent (dataframe): Dataframe with only data from a single contintent
    '''
    if continent:
        
        continent_list = ['America', 'Europe', 'Asia', 'Africa', 'Oceania']
        
        assert continent in continent_list, "Continent is not in continent_list"
            
        df_continent = df[df['Continent'] == continent]
        
    return df_continent

# %%
europe = select_continent(df_current, 'Europe')
europe.head()
# Out:
#            Year_week Continent  Country  ISO  Population  \
# Date
# 2020-09-23   2020-39    Europe  Albania  ALB   2877797.0
# 2020-09-23   2020-39    Europe  Armenia  ARM   2963243.0
# 2020-09-23   2020-39    Europe  Austria  AUT   9006398.0
# 2020-09-23   2020-39    Europe  Belarus  BLR   9449323.0
# 2020-09-23   2020-39    Europe  Belgium  BEL  11589623.0
#
#             Urban_Population_ratio  Pop_km2  Median_age  Total_deaths  \
# Date
# 2020-09-23                    0.63    105.0        36.0         370.0
# 2020-09-23                    0.63    104.0        35.0         942.0
# 2020-09-23                    0.57    109.0        43.0         777.0
# 2020-09-23                    0.79     47.0        40.0         796.0
# 2020-09-23                    0.98    383.0        42.0        9959.0
#
#             Total_deaths_per_100k  Weekday  Deaths  Deaths_s7  \
# Date
# 2020-09-23              12.857053        2     3.0          3
# ...

# %%
def rank_data(df_current, top_n = (None, None)):
    '''
    This function filters on the top n countries ranked on any of the following:
    
    - Population
    - Pop_km2
    - Urban_Population_ratio
    - Median_age
    - Deaths
    - Deaths_per_100k
    
    Args:
        df_current (dataframe): dataframe with just the latest date
        top_n (tuple): First element (str): variable name to base the ranking on
                        Second element (int): the n in top_n 


    Returns:
        df (dataframe): ranked data
    '''
    
    var_list = ['Population', 'Pop_km2', 'Urban_Population_ratio', 'Median_age', 'Total_deaths', \
                'Total_deaths_per_100k', 'Deaths', 'Deaths_per_100k', 'Deaths_s7', 'Deaths_per_100k_s7', 
                'Deaths_week', 'Deaths_lastweek', 'Infection_rate']
    
    # unpack tuple
    
    var = top_n[0]
    n = top_n[1]
    
    assert var in var_list
    
    # limiting n so that it is not more than the number of rows (capped)
    
    if n:
        tot_countries = df_current.shape[0]
        if n > tot_countries:
            n = tot_countries
            
    df = df_current.sort_values(by=[var], ascending=False)[:n]
    
    return df

# %%
rank_data(df_current, top_n = ('Population', 2))
# Out:
#            Year_week Continent Country  ISO    Population  \
# Date
# 2020-09-23   2020-39      Asia   China  CHN  1.439324e+09
# 2020-09-23   2020-39      Asia   India  IND  1.380004e+09
#
#             Urban_Population_ratio  Pop_km2  Median_age  Total_deaths  \
# Date
# 2020-09-23                    0.61    153.0        38.0        4634.0
# 2020-09-23                    0.35    464.0        28.0       90020.0
#
#             Total_deaths_per_100k  Weekday  Deaths  Deaths_s7  \
# Date
# 2020-09-23               0.321957        2     0.0          0
# 2020-09-23               6.523168        2  1085.0       1136
#
#             Deaths_per_100k_s7  Deaths_week  Deaths_lastweek  Infection_rate  \
# Date
# 2020-09-23            0.000000          0.0              0.0        0.000000
# 2020-09-23            0.082319       3268.0           8166.0        0.400196
#
#             Deaths_per_100k  Deaths_week_per_100k
# Date
# 2020-09-23         0.000000              0.000000
# ...

# %%
def prepare_barplot(continent=None, top_n = (None, None)):
    '''
    This funtion gets the current high level aggregated data suitable for bar plots.
    It is optional to filter on continent.
    It is also optional to filter on the top n countries ranked on any of the following:
    
    - Population
    - Pop_km2
    - Urban_Population_ratio
    - Median_age
    - Deaths
    - Deaths_per_100k
    
    Args:
        continent (str): The continent ('America', 'Europe', 'Asia', 'Africa', 'Oceania')
        top_n (tuple): First element (str): variable name to base the ranking on
                        Second element (int): the n in top_n 

    Returns:
        df_current (dataframe): dataframe with just the latest date prepared for barplot
    '''

    df_merged = merge_data()
    
    df_full = add_calculated_cols(df_merged)
    
    df_current = dates_choice(df_full)
    
    if continent:
        df_current = select_continent(df_current, continent)
        
    var_list = ['Population', 'Pop_km2', 'Urban_Population_ratio', 'Median_age', 'Total_deaths', \
                'Total_deaths_per_100k', 'Deaths', 'Deaths_per_100k', 'Deaths_s7', 'Deaths_per_100k_s7', \
                'Deaths_week', 'Deaths_lastweek', 'Infection_rate']
    
    # assert that top_n tuple input is valid in case two (no-None) elements are provided
    
    if (len(top_n) == 2) and (top_n[0] and top_n[1]):
        
        assert top_n[0] in var_list, "First tuple element in 'top_n' must be in var_list and of type String"
        assert isinstance(top_n[1], int) == True, "Second tuple element in 'top_n' must of type Integer"
    
        df_current = rank_data(df_current, top_n)
        
    df_current = df_current.reset_index().set_index('Country')
    
    return df_current

# %%
# Test: Prepare_barplot of Top 20 Deaths_per_100k in Asia

var = 'Total_deaths_per_100k'

df = prepare_barplot(top_n = ('Total_deaths_per_100k', 10))

df = df[[var]]

df
# Out:
#                 Total_deaths_per_100k
# Country
# Peru                        95.742263
# Belgium                     85.930311
# Spain                       66.376102
# Bolivia                     66.229636
# Brazil                      64.972421
# Chile                       64.578728
# Ecuador                     63.316699
# United Kingdom              61.796236
# United States               60.991656
# Italy                       59.141448

# %%
def prepare_time(continent=None, top_n = (None, None)):
    '''
    This funtion gets the daily data suitable for time series plots.
    It is optional to filter on continent.
    It is also optional to filter on the top n countries ranked on any of the following:
    
    - Population
    - Pop_km2
    - Urban_Population_ratio
    - Median_age
    - Deaths
    - Deaths_per_100k
    
    Args:
        continent (str) (optional): The continent ('America', 'Europe', 'Asia', 'Africa', 'Oceania')
        top_n (tuple) (optional): First element (str): variable name to base the ranking on
                        Second element (int): the n in top_n 

    Returns:
        df_current (dataframe): dataframe with just the latest date prepared for barplot
        
    '''
    
    # getting the dataframe prepared with historic data

    df_merged = merge_data()
    
    df_full = add_calculated_cols(df_merged)
    
    df = dates_choice(df_full, all_dates=True)
    
    # defining the beginning of time to be 9th of March 2020
    df = df[df.index > '2020-03-08']
    
    # list of countries and number of countries
    
    countries = df.Country.unique()

    tot_countries = df.shape[0]

    # setting a default (key) variable 'var' in case none is provided
    var = 'Total_deaths'
    
    
    # updating the key variable 'var' and 'n' from the input (optional)
    
    if top_n[0] and top_n[1]:
    
        var = top_n[0]
        n = top_n[1]
        if n > tot_countries:
            n = tot_countries
    else:
        n = tot_countries


    # make list of countries ordered by 'var' at the latest date
    last_date = df.index.max()

    df_last = df[df.index == last_date].sort_values(var, ascending=False)
    
    countrylist = list(df_last['Country'][:n])

    #df = df.reset_index()
    df = df[df['Country'].isin(countrylist)]


    return countrylist, df

# %%
def prepare_time_weekly(continent=None, top_n = (None, None)):
    '''
    This funtion gets the daily data suitable for time series plots - weekly version.
    It is optional to filter on continent.
    It is also optional to filter on the top n countries ranked on any of the following:
    
    - Population
    - Pop_km2
    - Urban_Population_ratio
    - Median_age
    - Deaths
    - Deaths_per_100k
    
    Args:
        continent (str) (optional): The continent ('America', 'Europe', 'Asia', 'Africa', 'Oceania')
        top_n (tuple) (optional): First element (str): variable name to base the ranking on
                        Second element (int): the n in top_n 

    Returns:
        df_current (dataframe): dataframe with historic weekly data
        
    '''
    
    # getting the dataframe prepared with historic data

    df_merged = merge_data()
    
    df_full = add_calculated_cols(df_merged)
    
    df = dates_choice(df_full, all_dates=False, weekly=True)
    
    # defining the beginning of time to be 9th of March 2020
    df = df[df.index > '2020-03-08']
    
    # list of countries and number of countries
    
    countries = df.Country.unique()

    tot_countries = df.shape[0]

    # setting a default (key) variable 'var' in case none is provided
    var = 'Total_deaths'
    
    
    # updating the key variable 'var' and 'n' from the input (optional)
    
    if top_n[0] and top_n[1]:
    
        var = top_n[0]
        n = top_n[1]
        if n > tot_countries:
            n = tot_countries
    else:
        n = tot_countries


    # make list of countries ordered by 'var' at the latest date
    last_date = df.index.max()

    df_last = df[df.index == last_date].sort_values(var, ascending=False)
    
    countrylist = list(df_last['Country'][:n])

    #df = df.reset_index()
    df = df[df['Country'].isin(countrylist)]


    return countrylist, df

# %%
# test function
countrylist, df = prepare_time_weekly(continent=None, top_n=('Deaths_week', 1000))
df.head()
# Out:
#            Year_week Continent      Country  ISO  Population  \
# Date
# 2020-03-15   2020-11      Asia  Afghanistan  AFG  38928346.0
# 2020-03-22   2020-12      Asia  Afghanistan  AFG  38928346.0
# 2020-03-29   2020-13      Asia  Afghanistan  AFG  38928346.0
# 2020-04-05   2020-14      Asia  Afghanistan  AFG  38928346.0
# 2020-04-12   2020-15      Asia  Afghanistan  AFG  38928346.0
#
#             Urban_Population_ratio  Pop_km2  Median_age  Total_deaths  \
# Date
# 2020-03-15                    0.25     60.0        18.0           0.0
# 2020-03-22                    0.25     60.0        18.0           1.0
# 2020-03-29                    0.25     60.0        18.0           4.0
# 2020-04-05                    0.25     60.0        18.0           7.0
# 2020-04-12                    0.25     60.0        18.0          18.0
#
#             Total_deaths_per_100k  Weekday  Deaths  Deaths_s7  \
# Date
# 2020-03-15               0.000000        6     0.0          0
# ...

# %%
df[df.Country == 'India']
# Out:
#            Year_week Continent Country  ISO    Population  \
# Date
# 2020-03-15   2020-11      Asia   India  IND  1.380004e+09
# 2020-03-22   2020-12      Asia   India  IND  1.380004e+09
# 2020-03-29   2020-13      Asia   India  IND  1.380004e+09
# 2020-04-05   2020-14      Asia   India  IND  1.380004e+09
# 2020-04-12   2020-15      Asia   India  IND  1.380004e+09
# 2020-04-19   2020-16      Asia   India  IND  1.380004e+09
# 2020-04-26   2020-17      Asia   India  IND  1.380004e+09
# 2020-05-03   2020-18      Asia   India  IND  1.380004e+09
# 2020-05-10   2020-19      Asia   India  IND  1.380004e+09
# 2020-05-17   2020-20      Asia   India  IND  1.380004e+09
# 2020-05-24   2020-21      Asia   India  IND  1.380004e+09
# 2020-05-31   2020-22      Asia   India  IND  1.380004e+09
# 2020-06-07   2020-23      Asia   India  IND  1.380004e+09
# 2020-06-14   2020-24      Asia   India  IND  1.380004e+09
# 2020-06-21   2020-25      Asia   India  IND  1.380004e+09
# ...

# %%
df[df.index == df.index.max()].sort_values(by='Deaths_week', ascending=False)
# Out:
#            Year_week Continent                   Country  ISO    Population  \
# Date
# 2020-09-20   2020-38      Asia                     India  IND  1.380004e+09
# 2020-09-20   2020-38   America             United States  USA  3.310027e+08
# 2020-09-20   2020-38   America                    Brazil  BRA  2.125594e+08
# 2020-09-20   2020-38   America                    Mexico  MEX  1.289328e+08
# 2020-09-20   2020-38   America                 Argentina  ARG  4.519577e+07
# 2020-09-20   2020-38   America                  Colombia  COL  5.088289e+07
# 2020-09-20   2020-38      Asia                      Iran  IRN  8.399295e+07
# 2020-09-20   2020-38   America                      Peru  PER  3.297185e+07
# 2020-09-20   2020-38      Asia                    Russia  RUS  1.459345e+08
# 2020-09-20   2020-38      Asia                 Indonesia  IDN  2.735236e+08
# 2020-09-20   2020-38    Europe                     Spain  ESP  4.675478e+07
# ...

# %%
countrylist
# Out:
# ['India',
#  'United States',
#  'Brazil',
#  'Mexico',
#  'Argentina',
#  'Colombia',
#  'Iran',
#  'Peru',
#  'Russia',
#  'Indonesia',
#  'Spain',
#  'Philippines',
#  'Iraq',
#  'South Africa',
#  'Turkey',
#  'Ukraine',
#  'France',
#  'Chile',
#  'Bolivia',
#  'Romania',
#  'Morocco',
#  'Saudi Arabia',
#  'Bangladesh',
#  'Ecuador',
#  'Guatemala',
#  'United Kingdom',
#  'Israel',
#  'Paraguay',
#  'Egypt',
#  'Costa Rica',
#  'Poland',
#  'Honduras',
#  'Italy',
#  'Panama',
#  'Ethiopia',
#  'Libya',
#  'Moldova',
#  'Dominican Republic',
#  'Myanmar',
#  'Bosnia and Herzegovina',
#  'Nepal',
#  'Oman',
#  'Venezuela',
#  'Japan',
#  'Algeria',
#  'Lebanon',
#  'Tunisia',
#  'Czechia',
#  'Canada',
#  'Hungary',
#  'North Macedonia',
#  'Portugal',
#  'Uzbekistan',
#  'Bulgaria',
#  'Kazakhstan',
#  'Pakistan',
#  'Germany',
#  'Australia',
#  'Greece',
#  'Netherlands',
#  'Belarus',
#  'Albania',
#  'Kenya',
#  'El Salvador',
#  'Jamaica',
#  'Switzerland',
#  'Croatia',
# ...

# %%
df = prepare_barplot()
df.head()
# Out:
#                   Date Year_week Continent  ISO  Population  \
# Country
# Afghanistan 2020-09-23   2020-39      Asia  AFG  38928346.0
# Albania     2020-09-23   2020-39    Europe  ALB   2877797.0
# Algeria     2020-09-23   2020-39    Africa  DZA  43851044.0
# Angola      2020-09-23   2020-39    Africa  AGO  32866272.0
# Argentina   2020-09-23   2020-39   America  ARG  45195774.0
#
#              Urban_Population_ratio  Pop_km2  Median_age  Total_deaths  \
# Country
# Afghanistan                    0.25     60.0        18.0        1446.0
# Albania                        0.63    105.0        36.0         370.0
# Algeria                        0.73     18.0        29.0        1698.0
# Angola                         0.67     26.0        17.0         159.0
# Argentina                      0.93     17.0        32.0       14376.0
#
#              Total_deaths_per_100k  Weekday  Deaths  Deaths_s7  \
# Country
# Afghanistan               3.714517        2     1.0          1
# ...

# %%
# Test: Prepare Choropleth
df = prepare_barplot()
var = 'Deaths_per_100k'

date = str(df.Date[0])[:10]
df = df[['ISO', var]]
print(date)
df
# Out:
# 2020-09-23
#                           ISO  Deaths_per_100k
# Country
# Afghanistan               AFG         0.002569
# Albania                   ALB         0.104246
# Algeria                   DZA         0.020524
# Angola                    AGO         0.012171
# Argentina                 ARG         0.938141
# Armenia                   ARM         0.134987
# Australia                 AUS         0.007843
# Austria                   AUT         0.066619
# Azerbaijan                AZE         0.019725
# Bangladesh                BGD         0.022467
# Belarus                   BLR         0.052914
# Belgium                   BEL         0.034514
# Benin                     BEN         0.000000
# Bolivia                   BOL         0.325537
# Bosnia and Herzegovina    BIH         0.365762
# Botswana                  BWA         0.000000
# Brazil                    BRA         0.000000
# Bulgaria                  BGR         0.172700
# ...

# %%
def prepare_time(continent=None, top_n = (None, None)):
    '''
    This function gets the daily data suitable for time series plots.
    It is optional to filter on continent.
    It is also optional to filter on the top n countries ranked on any of the following:
    
    - Population
    - Pop_km2
    - Urban_Population_ratio
    - Median_age
    - Deaths
    - Deaths_per_100k
    
    Args:
        continent (str) (optional): The continent ('America', 'Europe', 'Asia', 'Africa', 'Oceania')
        top_n (tuple) (optional): First element (str): variable name to base the ranking on
                        Second element (int): the n in top_n 

    Returns:
        df_current (dataframe): dataframe with just the latest date prepared for barplot
        
    '''
    
    # getting the dataframe prepared with historic data

    df_merged = merge_data()
    
    df_full = add_calculated_cols(df_merged)
    
    df = dates_choice(df_full, all_dates=True)
    
    # defining the beginning of time to be 9th of March 2020
    df = df[df.index > '2020-03-08']
    
    # list of countries and number of countries
    
    countries = df.Country.unique()

    tot_countries = df.shape[0]

    # setting a default (key) variable 'var' in case none is provided
    var = 'Total_deaths'
    
    
    # updating the key variable 'var' and 'n' from the input (optional)
    
    if top_n[0] and top_n[1]:
    
        var = top_n[0]
        n = top_n[1]
        if n > tot_countries:
            n = tot_countries
    else:
        n = tot_countries


    # make list of countries ordered by 'var' at the latest date
    last_date = df.index.max()

    df_last = df[df.index == last_date].sort_values(var, ascending=False)
    
    countrylist = list(df_last['Country'][:n])

    #df = df.reset_index()
    df = df[df['Country'].isin(countrylist)]


    return countrylist, df

# %% [markdown]
# ### Data Exploration <a class="anchor" id="chapter4"></a>

# %% [markdown]
# We will explore historic daily, historic weekly and latest day (current) data. We have `df_historic`, `df_weekly` and `df_current` from last chapter to utilize for this purpose.
#
# We wish to compare our Sweden data with other countries whereever it makes sense.

# %% [markdown]
# #### Current Data    <a class="anchor" id="section_4_1"></a>

# %% [markdown]
# We check some ranked data. (a lot of this are of variable not used further in our project)

# %%
# Continent wise distribution

Countries_per_continent = df_current.groupby('Continent').count()['Country'].sort_values(ascending=False)

print("\nTotal number of countries included: {}\n".format(Countries_per_continent.sum()))

print(Countries_per_continent)
print()

# Urban Population ratio: High vs. Low

print('\nTop 15 in Urban Population ratio:\n')
print(df_current.sort_values('Urban_Population_ratio', ascending=False)[:15][['Country', 'Urban_Population_ratio', 'Deaths_per_100k']].to_string(index=False))

print()

print('\nBottom 5 in Urban Population ratio:\n')
print(df_current.sort_values('Urban_Population_ratio')[:5][['Country', 'Urban_Population_ratio', 'Deaths_per_100k']].to_string(index=False))

print()

# Median Age: High vs. Low

print('\nTop 15 in Median Age:\n')
print(df_current.sort_values('Median_age', ascending=False)[:15][['Country', 'Median_age', 'Deaths_per_100k']].to_string(index=False))

print()

print('\nBottom 5 in Median Age:\n')
print(df_current.sort_values('Median_age')[:5][['Country', 'Median_age', 'Deaths_per_100k']].to_string(index=False))
# Out:
# Total number of countries included: 151
#
# Continent
# Africa     44
# Europe     41
# Asia       40
# America    23
# Oceania     3
# Name: Country, dtype: int64
#
#
# Top 15 in Urban Population ratio:
#
#      Country  Urban_Population_ratio  Deaths_per_100k
#    Singapore                    1.00         0.000000
#    Hong Kong                    1.00         0.013339
#      Belgium                    0.98         0.034514
#        Qatar                    0.96         0.034832
#      Uruguay                    0.96         0.028787
#      Iceland                    0.94         0.000000
#    Argentina                    0.93         0.938141
#       Israel                    0.93         0.462132
#        Japan                    0.92         0.004744
#  Netherlands                    0.92         0.035016
#       Jordan                    0.91         0.019602
#      Denmark                    0.88         0.034529
#       Brazil                    0.88         0.000000
# ...

# %% [markdown]
# **Some nice Choropleth map plots further down :)**

# %%
def prepare_geo(df_current):
    '''
    This function merges df_current with a geopandas dataframe read from file.
    This is just for the notebook; the choropleth charts in the plotly web app
    are simpler; it just uses ISO codes.
    
    Args:
        df_current: Dataframe of latest data

    Returns:
        df (dataframe): data including multipolygon coordinates to be used in geographic plots
    '''
    
    # read the geo data
    
    fp = 'data/ne_10m_admin_0_countries.shp'

    gdf = gpd.read_file(fp)
    
    # clean geo data
    
    gdf = gdf.rename(columns={"ADMIN": "Country", "ADM0_A3": "Short"})
    
    gdf = gdf[['Country', 'Short', 'geometry']]
    gdf.columns = ['Country', 'ISO', 'geometry']
    
    
    # merge with current data
    df_all = df_current
    
    df = gdf.merge(df_all, how='left', on='ISO').drop(columns=['Date', 'Country_y'])
    
    
    # final cleaning
    df.rename(columns={"Country_x": "Country"}, inplace = True)
    df.fillna(0, inplace = True)
    
    return df

# %%
def plot_geo(colname, continent=None):
    '''
    This function will plot a choropleth chart of the continent.
    It will work best with Europe, America or Asia, as I have customized the map ranges.
    
    Args:
        colname (str): Name of variable
        continent (str): Continent (America, Europe, Africa, Asia, Oceania)

    Returns:
        this function does not return anything
    '''
    
    # prepare data
    data = prepare_geo(df_current.reset_index())
    
    # exclude the south pole
    data = data[data.Country!="Antarctica"]

    if continent:
        data = data[data.Continent == continent] 

    fig, ax = plt.subplots(1, 1, figsize=(16, 12))
    
    
    if not continent:
        fontsize = 6
        
    elif continent == 'Europe':
        
        ax.set(xlim=(-24, 40), ylim=(35, 75))
        fontsize = 8
        ax.text(1, 46, 'France', fontsize=fontsize)
        ax.text(8, 62, 'Norway', fontsize=fontsize)
        
    elif continent == 'America':
        
        ax.set(xlim=(-130, -30), ylim=(-55, 75))
        fontsize = 10     
        ax.text(-103, 38, 'USA', fontsize=fontsize)    
        ax.text(-107, 53, 'Canada', fontsize=fontsize)
        
    elif continent == 'Asia':
        ax.set(xlim=(20, 145), ylim=(-10, 75))
        fontsize = 8     
    else:
        fontsize = 8

    # plot choropleth chart

    data.plot(column=colname, ax=ax, legend=True, cmap='Wistia', legend_kwds={'label': "{}".format(colname), 
                                                                      'orientation': "vertical"})

    plt.xlabel("Longitude")
    plt.ylabel("Latitude")
   

    plt.title('{}: {}\n'.format(continent, colname),  fontsize=18)
    

    skip_list = ['Norway', 'France', 'United States of America', 'Canada']

    for idx, row in data.iterrows():
        
        if (len(str(row['Country'])) > 3) & (str(row['Country']) not in skip_list):
            plt.annotate(s=row['Country'], xy=row['geometry'].centroid.coords[0],
                     horizontalalignment='center', fontsize=fontsize)

# %%
plot_geo(colname = 'Deaths_per_100k', continent = 'Europe')

# %%
plot_geo(colname = 'Deaths_per_100k', continent = 'America')

# %%
plot_geo(colname = 'Deaths_per_100k', continent = 'Asia')

# %% [markdown]
# #### Historic Daily Data    <a class="anchor" id="section_4_2"></a>

# %%
# preparing some countries for easy exploring...


# Sweden - our main country of interest

sweden = df_historic[df_historic.Country == 'Sweden']


# USA because they are have been struck by the pandemic wave very parallel in time to Sweden

usa = df_historic[df_historic.Country == 'United States']


# Couple of other European countries; Italy as they got big problems early and
# served as a warning sign to Europe and to the rest of the world, and Germany
# as it is the European country with the highest population

italy = df_historic[df_historic.Country == 'Italy']
germany = df_historic[df_historic.Country == 'Germany']


# Sweden's neighbors - the nordic countries

norway = df_historic[df_historic.Country == 'Norway']
finland = df_historic[df_historic.Country == 'Finland']
denmark = df_historic[df_historic.Country == 'Denmark']

# %%
plt.figure(figsize=(12,6))
plt.xlabel('Date')
plt.ylabel('Deaths per 100,000 people')

ax1= sweden.Deaths_per_100k_s7.plot(color='blue', grid=True, label='Sweden')
ax2 = usa.Deaths_per_100k_s7.plot(color='red', grid=True, label='USA')

plt.legend()
plt.title('Sweden vs. USA - Deaths per 100,000')
plt.show()

# %% [markdown]
# We see that Sweden and United States have followed a similar curve. A bit alarming to see that Sweden has a higher peak, but it's reassuring (and very surprising!) that the death volumes go down at a similar rate. Surprising because United States have had a larger degree of lockdown, and other measures, such as, more people wearing masks. Most of all it's reassuring that, for both countries, it seems the citizens are winning and the virus is losing. The virus is going toward zero, but is it going fast enough down? People are dying as long as the "wave" is ongoing.

# %%
plt.figure(figsize=(12,6))
plt.xlabel('Date')
plt.ylabel('Deaths per 100k')

ax1= sweden.Deaths_per_100k_s7.plot(color='blue', grid=True, label='Sweden')
ax2 = germany.Deaths_per_100k_s7.plot(color='black', grid=True, label='Germany')
ax3 = italy.Deaths_per_100k_s7.plot(color='green', grid=True, label='Italy')

plt.legend()
plt.title('Sweden vs. Germany and Italy')
plt.show()

# %% [markdown]
# We see that Italy had an even bigger peak than Sweden, and it came 3 weeks earlier. Germany have much lower deaths numbers, at least in relative terms.

# %%
plt.figure(figsize=(12,6))
plt.xlabel('Date')
plt.ylabel('Deaths per 100,000 people')

ax1= sweden.Deaths_per_100k_s7.plot(color='blue', grid=True, label='Sweden')
ax2 = norway.Deaths_per_100k_s7.plot(color='purple', grid=True, label='Norway')
ax3 = denmark.Deaths_per_100k_s7.plot(color='red', grid=True, label='Denmark')
ax4 = finland.Deaths_per_100k_s7.plot(color='green', grid=True, label='Finland')



plt.legend()
plt.title('Sweden vs. the rest of the Nordics')
plt.show()

# %% [markdown]
# We zoom in on the Nordics. Norway, Sweden and Denmark especially have long historic bonds and are similar in language, culture, mindset etc. Regardless, clearly Sweden is the odd one out, and the main reason is their gung-ho strategy not to go into lockdown, but keep businesses open and reach herd immunity sooner rather than later.

# %% [markdown]
# #### Historic Weekly Data    <a class="anchor" id="section_4_3"></a>

# %%
# We do the same exercise as we did for historic daily data, now for historic weekly

swedenw = df_weekly[df_weekly.Country == 'Sweden']
norwayw = df_weekly[df_weekly.Country == 'Norway']
finlandw = df_weekly[df_weekly.Country == 'Finland']
denmarkw = df_weekly[df_weekly.Country == 'Denmark']
usaw = df_weekly[df_weekly.Country == 'United States']
germanyw = df_weekly[df_weekly.Country == 'Germany']
italyw = df_weekly[df_weekly.Country == 'Italy']

# %%
deaths_sweden = int(swedenw.Deaths_week.sum())
deaths_norway = int(norwayw.Deaths_week.sum())
deaths_finland = int(finlandw.Deaths_week.sum())
deaths_denmark = int(denmarkw.Deaths_week.sum())

print('Total deaths Sweden: {}'.format(deaths_sweden))
print('Total deaths Denmark: {}'.format(deaths_denmark))
print('Total deaths Finland: {}'.format(deaths_finland))
print('Total deaths Norway: {}'.format(deaths_norway))
# Out:
# Total deaths Sweden: 5865
# Total deaths Denmark: 638
# Total deaths Finland: 339
# Total deaths Norway: 267

# %% [markdown]
# This continues into the next chapter: Results
#
# It was originally part of the exploration, but I didn't want to duplicate it, so I moved it into the next section.

# %% [markdown]
# ### Results <a class="anchor" id="chapter5"></a>

# %% [markdown]
# Now, looking at the weekly relative death numbers chart for the Nordic countries, it will look similar to a chart we saw in the Explore Historic Daily data- section. The only difference, of course, is that this time each data point is the accrued deaths for a week's period.

# %%
plt.figure(figsize=(12,6))
plt.xlabel('Date')
plt.ylabel('Weekly deaths / 100k')

ax = swedenw.Deaths_week_per_100k.plot(color='blue', grid=True, label='Sweden')
ax = denmarkw.Deaths_week_per_100k.plot(color='red', grid=True, label='Denmark')
ax = finlandw.Deaths_week_per_100k.plot(color='green', grid=True, label='Finland')
ax = norwayw.Deaths_week_per_100k.plot(color='purple', grid=True, label='Norway')

plt.legend()
plt.title('Weekly deaths per 100,000 people')
plt.show()

# %% [markdown]
# We clearly see the dramatic difference. And the result so far of this still ongoing pandemic wave is more than 5,000 deaths in Sweden and just a few hundred deaths in the neighboring countries.
#
# Norway, Sweden and Denmark, in particular, have strong historic bonds and are similar in language, culture, mindset etc. Regardless, clearly Sweden is the odd one out, and the main reason is their gung-ho strategy not to go into lockdown, but keep businesses open and reach herd immunity sooner rather than later.
#
# We cannot know for sure if Swedens strategy is flawed. There could come later waves and if the Swedish people are close to herd immunity, the impact in terms of deaths could be softer next time.
#
# However, at this point, **it looks like we are winning and the virus is loosing**, in which case taking a more careful path of lockdowns and social distancing seems like the winning formula. So let's assume this is correct, and find out what scenarios lie ahead for Sweden.

# %% [markdown]
# We zoom in on Sweden alone from the peak onwards

# %%
plt.figure(figsize=(12,6))
plt.xlabel('Date')
plt.ylabel('Weekly deaths')

swedenw = swedenw[swedenw.index > '2020-04-15']

ax = swedenw.Deaths_week.plot(color='blue', grid=True, label='Sweden')

plt.legend()
plt.title('Sweden: Weekly Number of Deaths')
plt.show()

# %% [markdown]
# Luckily, the curve has come down for Sweden from more than 600 weekly deaths at the peak. Just recently this week, as I write this, it dropped under 200 weekly deaths.

# %%
plt.figure(figsize=(12,7))
plt.xlabel('Date')
plt.ylabel('Infection Rate estimates')


swedenw = swedenw[swedenw.index > '2020-04-15']

ax = swedenw.Infection_rate.plot(color='blue', grid=True, label='Sweden')

plt.legend()
plt.title('Sweden: Infection Rate estimates')
plt.show()

# %% [markdown]
# The infection rate is jumping a bit up and down, mostly in the range 0.7 to 1.3. The first half of June was great with three consequtive weeks around 0.7-0.8. That led to a drop in the weekly deaths from around 400 to around 200, so it had a huge effect.

# %% [markdown]
# Before we project into the future, let's see how that 200 number compares to the neighbors:

# %%
# let's look at the current situation in Sweden compared to the other nordic countries
last_weekly_deaths_sweden = swedenw.iloc[-1:].Deaths_week.astype(str).astype(float).tolist()[0]
last_weekly_deaths_norway = norwayw.iloc[-1:].Deaths_week.astype(str).astype(float).tolist()[0]
last_weekly_deaths_denmark = denmarkw.iloc[-1:].Deaths_week.astype(str).astype(float).tolist()[0]
last_weekly_deaths_finland = finlandw.iloc[-1:].Deaths_week.astype(str).astype(float).tolist()[0]

print('During last week of June 2020 the number of deaths in Sweden was: {}'.format(int(last_weekly_deaths_sweden)))

print('\nMeanwhile in the neighboring countries the number of deaths were as follows...\n')
print('Norway: {}'.format(int(last_weekly_deaths_norway)))
print('Denmark: {}'.format(int(last_weekly_deaths_denmark)))
print('Finland: {}'.format(int(last_weekly_deaths_finland)))
# Out:
# During last week of June 2020 the number of deaths in Sweden was: 19
#
# Meanwhile in the neighboring countries the number of deaths were as follows...
#
# Norway: 2
# Denmark: 7
# Finland: 2

# %% [markdown]
# The weekly death count has come all the way down to 140, but meanwhile the others have nearly no deaths. Almost eradicated!

# %% [markdown]
# The following function gives us the outlook for any country. We will use it for Sweden.

# %%
def get_outlook(start_date, current_weekly_deaths, infection_rate):
    '''
    This function estimates weekly deaths until it reaches zero based on
    infection rate and a current weekly death number at a start date.
    
    Args:
        start_date (str): the current date (latest data point)
        current_weekly_deaths (int): number of current weekly deaths
        infection_rate (float): number between 0 and 1

    Returns:
        df (dataframe): data of weekly deaths and accrued deaths
        end_date (str): end date when weekly deaths reach zero
        future_deaths (int): number of deaths between start_date and end_date
    '''
    
    
    date_list = []
    date_time_obj = dt.datetime.strptime(start_date, '%Y-%m-%d')
    
    deaths_list = []
    
    acc_deaths_list = []
    acc_deaths = 0.0

    while current_weekly_deaths > 0.1:
        date_time_obj = date_time_obj + timedelta(days=7) 
        date_list.append(date_time_obj.strftime('%Y-%m-%d'))
        current_weekly_deaths = current_weekly_deaths*infection_rate
        deaths_list.append(np.round(current_weekly_deaths))
        acc_deaths = acc_deaths + current_weekly_deaths
        
        acc_deaths_list.append(np.round(acc_deaths))
        
    x = tuple(zip(date_list, deaths_list, acc_deaths_list))
    df = pd.DataFrame(x)
    df.columns = ['Date', 'Weekly_deaths', 'Acc_weekly_deaths']
   
    end_date = date_list[-1]
    future_deaths = acc_deaths_list[-1]
    

    return df, end_date, future_deaths

# %% [markdown]
# We check the current outlook for Sweden (2020-07-05) for R of 0.9, 0.8 and 0.7 respectively, and current weekly deaths of 140.

# %%
infection_rate = 0.9
start_date = '2020-07-05'
current_weekly_deaths = 140

df07, end_date, future_deaths = get_outlook(start_date=start_date, current_weekly_deaths = current_weekly_deaths, infection_rate=infection_rate)
df07.set_index('Date', inplace=True)

plt.figure(figsize=(18,4))
plt.xlabel('Date')
plt.ylabel('Deaths')

ax = df07.Acc_weekly_deaths.plot(kind='bar', color='grey', label='Accrued deaths');
ax = df07.Weekly_deaths.plot(kind='bar', color='black', label='Weekly deaths');

plt.title('Sweden Outlook with R = 0.9')
plt.legend()

plt.show()

print('End date: {}'.format(end_date))
print('Deaths from provided start date: {}'.format(future_deaths))
# Out:
# End date: 2021-10-31
# Deaths from provided start date: 1259.0

# %%
infection_rate = 0.8
start_date = '2020-07-05'
current_weekly_deaths = 140

df07, end_date, future_deaths = get_outlook(start_date=start_date, current_weekly_deaths = current_weekly_deaths, infection_rate=infection_rate)
df07.set_index('Date', inplace=True)

plt.figure(figsize=(10,4))
plt.xlabel('Date')
plt.ylabel('Deaths')

ax = df07.Acc_weekly_deaths.plot(kind='bar', color='grey', label='Accrued deaths');
ax = df07.Weekly_deaths.plot(kind='bar', color='black', label='Weekly deaths');

plt.title('Sweden Outlook with R = 0.8')
plt.legend()

plt.show()

print('End date: {}'.format(end_date))
print('Deaths from provided start date: {}'.format(future_deaths))
# Out:
# End date: 2021-02-21
# Deaths from provided start date: 560.0

# %%
infection_rate = 0.7
start_date = '2020-07-05'
current_weekly_deaths = 140

df07, end_date, future_deaths = get_outlook(start_date=start_date, current_weekly_deaths = current_weekly_deaths, infection_rate=infection_rate)
df07.set_index('Date', inplace=True)

plt.figure(figsize=(7,4))
plt.xlabel('Date')
plt.ylabel('Deaths')

ax = df07.Acc_weekly_deaths.plot(kind='bar', color='grey', label='Accrued deaths');
ax = df07.Weekly_deaths.plot(kind='bar', color='black', label='Weekly deaths');

plt.title('Sweden Outlook With R = 0.7')
plt.legend()

plt.show()

print('End date: {}'.format(end_date))
print('Deaths from start date: {}'.format(future_deaths))
# Out:
# End date: 2020-11-29
# Deaths from start date: 326.0

# %% [markdown]
# Wow, that is a huge difference from R of 0.9 to R of 0.7. End date will be around 1-Dec this year instead of 1-Nov 2021! Deaths will be 326 instead of 1259. That is almost a thousand lives!

# %% [markdown]
# **Justification / Issues**
#
# I did have some issues with the deployment. The steps for addition of calculated columns (feature engineering) took too long and resulted in an error code 12 in the Heroku application, which was a timeout error. I tried to refactor the code and avoid single cell updates, and got it down from 15 to 5 seconds by using concat instead, but it still kept crashing. I had to remove the smoothed (seven day moving average) variables. This applied to the web app, not the notebook.

# %% [markdown]
# ### Conclusion <a class="anchor" id="chapter6"></a>

# %% [markdown]
# It was really cool to get my first web app up and running on Heroku, and the topic of the COVID-19 virus spread felt meaningful. The choropleth plotly maps displayed on the web app are quite nice and interactive. It is possible, for example, to zoom in on the world map to a region of interest. Along with the line graphs it gives good information about both absolute and relative death counts.
#
# I did have some issues with the deployment, as explained in previous section, but at least the web app is working.
#
# I think I managed to show that it is possible to understand the dynamics of the decease by simply focusing on the 'Deaths' statistic and derive an estimate of the infection rate (R) from that.
#
# We saw that how Sweden stood out from the other Nordic countries with their less strict policies when it came to lockdown and social distancing. I showed some future scenarios, and we saw the huge difference from an R of 0.9 to an R of 0.7. End date will be around 1-Dec this year instead of 1-Nov 2021! Deaths will be 326 instead of 1259. That is almost a thousand lives!
#
# So, for the sake of the Swedish citizens, I really hope the Swedish government can implement some degree of lockdown, until an R of around 0.7 (or lower) is achievable.

# %% [markdown]
# ### Improvement <a class="anchor" id="chapter7"></a>
#
# Some ideas to improve / build on this project:
#
#     - Add some climate data to check whether climate matters for the virus spread
#     - Add data from blood samples (are there anomalies in iron, vitamin levels etc. for those who get hospitalized?)
#     - Add more advanced model / machine learning layer
#     - Over time check for signs that the virus might get weaker or stronger in terms of how deadly it is.
