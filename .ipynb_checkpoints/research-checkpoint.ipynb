# %% [markdown]
# ### Capstone Project:
#
# # 2020 Pandemic and the Curious Case of Sweden
#
# #### By Truls Møller 2020-07-07

# %% [markdown]
# ### Introduction

# %% [markdown]
# In the midst of crisis I seek to understand the nature of the decease &mdash; and the consequences of our response.
#
# I will start with a global view, and then I will zoom in on Sweden.
#
# Sweden stands out because they have not applied the common lockdown strategy. Instead, businesses and schools have been kept open. To a large degree it has been business as usual for the Swedish population. I live "next door" in Norway, where lockdown has been strict and sosial distancing has been practiced, and it will be interesting to look into the consequences for Sweden and even project into the future.
#
# I will give you `deaths` statistics.
#
# I will give you estimates of the `Infection rate (R)`.
#
# And it will be displayed in a web app that can easily be maintained.
#
# The results will let me answer some fundamental questions of mine, filed under the chapter 'Business Questions'.

# %% [markdown]
# ### Background

# %% [markdown]
# It started in Wuhan, China. Of the first 425 confirmed cases, the majority (55%) with onset before January 1, 2020, were linked to the Huanan Seafood Wholesale Market. The mean incubation period was 5.2 days. In its early stages, the epidemic doubled in size every 7.4 days.
#
#
#
# Everyone hoped that the virus would be stopped, even though there were a few cases outside China. On the 11th of March, however, WHO made the assessment that COVID-19 could be characterized as a pandemic.
# https://www.who.int/news-room/detail/29-06-2020-covidtimeline
#
# **You can't spell pandemic without panic!**  ie. a sudden sensation of fear. And that was the common experience for people all over the world when the graveness of the situation became known. Could it be as deadly as the Spanish Flu of 1918, which killed around 1 percent of the world population? Could it be worse?
#
# Attempts were made by governments, health orginizations, universities, statisticians, data analysts, data scientists etc. to understand how the virus behaved. Not all models were great. It was a big challenge. What data could be trusted?

# %% [markdown]
# ### Understanding of COVID-19 Virus
#
# Here is a Q & A on the current understanding how the virus "works". It will also highlight some of the complexity.
#
#     1. How many get infected by the virus but has no (serious) symptoms?
#
# Answer: The dark numbers is a big issue. It's good if they are large. Then the true mortality rate is lower, and we would reach herd immunity sooner, which again would lower the infection rate (R). It's still a challenge that we do not know the dark numbers, and they will vary a lot from country to country depending on how many people are tested.
#
#     2. Would you be immune if you had it?
#
# Answer: Most likely. Repeat cases have not been documented. However, it is too soon to tell if immunity could be lost over time.
#
#     3. Viruses are known to mutate. Will COVID-19 get stronger or milder over time?
#
# Answer: The virus is mutating, but very slowly, and the copies are not far from the original virus. This type of virus (RNA) is more likely to mutate into a weaker version. Overall that's a good thing. However, when such viruses get weaker, they tend to transfer more easily, which again would increase the infection rate (R). Source:
# [healthline.com](https://www.healthline.com/health-news/what-to-know-about-mutation-and-covid-19)

# %% [markdown]
# ### Business Questions
#
#     1. What is the current global picture of how many lives have been lost to the COVID-19 virus?
#
#     2. Looking at the top 10 countries based on highest number of deaths relative to population, how has the development been over time?
#
#     3. What has Sweden's R value been since March 2020, and how does it compare to its neighboring countries?
#
#     4. What scenarios lies ahead for Sweden?

# %% [markdown]
# ### Strategy
#
# I shall keep in mind from the start that my code is formatted well with lots of comments and uses **DRY principles**. **PEP8** is used as a guideline for best coding practices. I will also use best practices from the software engineering and communication lessons that I have completed as part of my Data Scientist Nanodegree at Udacity.
#
# Once I have the data, I will do most of the exploring in this **Jupyter Notebook**. The **Pandas** library will be key and I'll add other libraries whenever I need them. Then the key visualizations will be deployed to a web app hosted on **Heroku**. I will get the web app up and running quickly and add content when it feels ready. I will not use any machine learning for this project.
#
# I think the order of things will look like this:
#
#     - Set up local and Github repo
#     - Add readme file
#     - Gather data compiled by John Hopkins University. Automate a way updating on a daily basis.
#     - Gather data on country level: Population, ISO-codes etc. Static data on file will do.
#     - Clean and merge data into a Pandas DataFrame
#     - Prepare data for visualizations that will help answer business questions
#     - Deploy first content to web app
#     - Explore data, decide metrics
#     - Conclusions to business questions
#     - Finalize web app
#     - Some discussion on possible future improvements
#     - Finalize readme file

# %% [markdown]
# ### Data

# %% [markdown]
# Sources of datasets:
#
# Updated through this notebook:
# - covid-19 related datasets: https://www.kaggle.com/sudalairajkumar/novel-corona-virus-2019-dataset/discussion/136061
#
# Downloaded once:
# - population_by_country: https://www.kaggle.com/tanuprabhu/population-by-country-2020
# - natural earth polygon shapes of countries: https://www.naturalearthdata.com/downloads/10m-cultural-vectors/10m-admin-0-countries/

# %% [markdown]
# ### Metrics
#
# In order to address the business questions I will need to look at total deaths and daily deaths, preferably in relative terms, ie. compared to the population.
#
# #### List of Metrics
#
# Assumptions and comments given below each item.
#
#
#     1. 'Population'
#
#     Assumption: Population numbers are nearly static in the course of a few months
#
#     Comment: It's not perfect to use static numbers for population. However, it shouldn't be an issue over a few months. If the tracking is extended to last for years, it would be wise to update the population numbers, of course.
#
#     2. 'Total_deaths'
#     3. 'Total_deaths_per_100k' (derived from 'Total_deaths' and 'Population')
#     4. 'Deaths'                (derived from 'Total_deaths', means new daily)
#     5. 'Deaths_per_100k'       (derived from 'Deaths' and 'Population')
#     6. 'Deaths_s7'             (derived from 'Deaths')
#     7. 'Deaths_per_100k_s7'    (derived from 'Deaths_per_100k')
#     8. 'Deaths_week'           (derived from 'Deaths', means sum of new daily for the past 7 days)
#     9. 'Deaths_lastweek'       (derived from 'Deaths', means sum of new daily for the past 14-8 days)
#
#     Assumption: Reported numbers on 'Total_deaths' are accurate
#
#     Comment: Again it's not a perfect assumption, as there are different practices in different countries on determining the cause of death. For instance, if someone who is confirmed to be infected dies of heart failure, it could be labeled as 'heart failure' even though the underlying reason was the corona virus. There are also countries not all of the population are registered as citizens; they are outside the system. However, mostly, the count of deaths is trustworthy and it will give a very good indication of the true number of casualities due to the virus.
#
#     'Total_deaths_per_100k',
#        'Deaths_s7', 'Deaths_per_100k_s7',
#        'Deaths_week', 'Deaths_lastweek', 'Infection_rate'
#
#
#     10. 'Infection_rate'       (derived from 'Deaths_week' and 'Deaths_lastweek')
#
#     Assumption: R can be estimated from a weekly increase in deaths: R = Deaths_week_n/Deaths_week_n_minus_1
#
#     Comment: This is based on incubation time, and using weekly sums, there will be a smoothing effect, which should reduce some noise in the trend curve.

# %%
import os
import zipfile
import datetime as dt
from datetime import timedelta

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt


import geopandas as gpd
import descartes

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline
pd.set_option('display.max_columns', 50)
pd.set_option('display.max_rows', 200)

# %% [markdown]
# We will download covid-19 data programmatically. Currently there are updates on a daily basis.
#
# We will follow these steps:
#
# - Rename current file `data/covid_19_data.csv` by adding a `yymmdd` date extension to the file name and thereby, in effect, archiving it.
# - Download new file. Currently it comes compressed as a zip file, hence our target file is extracted and the zip file gets deleted.

# %%
# Setting file name and path of data files

# 1) The covid_19 data file

DATA_FOLDER_PATH = os.path.join(os.path.curdir, 'data')
DATA_NAME = 'covid_19_data.csv'
DATA_PATH = os.path.join(DATA_FOLDER_PATH, DATA_NAME)

# 2) The population data file

POPDATA_NAME = 'population_2020_for_johnhopkins_data.csv'
POPDATA_PATH = os.path.join(DATA_FOLDER_PATH, POPDATA_NAME)

# Making sure we have the correct path to the data. 
# This should be the case if this notebook was opened 
# in the root directory of the web app

required_data_path = './data/covid_19_data.csv'
required_popdata_path = './data/population_2020_for_johnhopkins_data.csv'

assert DATA_PATH == required_data_path, 'Error: Working directory must be the root directory of the web app'
print('Great. The path is correct for the covid-19 data.')
assert POPDATA_PATH == required_popdata_path, 'Error: Working directory must be the root directory of the web app'

print('Great. The path is correct for the population data.')
# Out:
# Great. The path is correct for the covid-19 data.
# Great. The path is correct for the population data.

# %% [markdown]
# Next we create three functions, that we will help us in the chore of updating the covid-19 data.

# %%
def archive_data(file_name, file_path):
    '''
    This function archives the old data file by renaming it with a date suffix in the format yymmdd,
    and then it prints a confirmation that the old data was archived including the name of the archived file
    
    Args:
        file_name (str): name of covid-19 data file
        file_path (str): path to covid-19 data file

    Returns:
        this function does not return anything
    '''

    file_full_path = os.path.join(file_path, file_name)

    try:
        mtime = os.path.getmtime(file_full_path)
        last_modified_time = dt.datetime.fromtimestamp(mtime) 
        last_data_date = last_modified_time - timedelta(days=1)
        date_extention = str(last_data_date.year)[2:].zfill(2) + str(last_data_date.month).zfill(2) + str(last_data_date.day).zfill(2)
        new_file_name = file_name[:-4] + date_extention + file_name[-4:]
        new_file_full_path = os.path.join(file_path, new_file_name)
        os.rename(file_full_path, new_file_full_path)
        print("- Old data file archived as: '{}'".format(new_file_name))
        print()
    except OSError:
        mtime = 0

# %%
def download_data(file_name, file_path):
    '''
    This function programmatically downloads the new data file from kaggle to the 'data' folder
    in the root directory of the web app. The new data file is compressed into .zip format
    
    Args:
        file_name (str): name of covid-19 data file
        file_path (str): path to covid-19 data file

    Returns:
        this function does not return anything
    '''
    
    # !kaggle datasets download -d sudalairajkumar/novel-corona-virus-2019-dataset -f $file_name -p $file_path --force

# %%
def extract_zip_file(file_name, file_path):
    '''
    This function unzips the compressed new data file found in the 'data' folder
    in the root directory of the web app. Then the zip file is deleted.
    
    Args:
        file_name (str): name of covid-19 data file
        file_path (str): path to covid-19 data file

    Returns:
        this function does not return anything
    '''
    
    for i,file in enumerate(os.listdir(file_path)):
        # looping through the files in the data folder, we search for the one ending with ".zip"
        if file.endswith(".zip"):
            try:
                # we obtain the zip file name, its full path and unzip it in the same folder
                zip_file_name = os.path.basename(file)
                zip_full_path = os.path.join(file_path, zip_file_name)
                
                with zipfile.ZipFile(zip_full_path, 'r') as zip_ref:
                    zip_ref.extractall(file_path)
                
                print()
                print("- New file extracted from compressed file to data folder as: '{}'".format(file_name))
                print()
                os.remove(zip_full_path)
                print('- Zip file deleted post extraction.')
            except OSError:
                pass

# %% [markdown]
# We utilize the above three functions in our main function for updating the covid-19 data: `get_latest_data()`

# %%
def get_latest_data(file_name, file_path):
    
    '''
    This function is our main function for updating the covid-10 data. It will utilize our
    three helper functions 'archive_data()', 'download_data()' and 'extract_zipfile()' for completing 
    a sequence of tasks:
    
    - Rename current file data/covid_19_data.csv by adding a yymmdd date extension to the file name 
    and thereby, in effect, archiving it.
    - Download new file, which is compressed into .zip format
    - Extract data file 'covid_19_data.csv' from zip-file
    - Delete zip-file
    
    For each task in the sequence a confirmation is printed.
    Finally, a confirmation is printed once the full sequence is successfully completed: 
    'COMPLETED sequence for updating data successfully!'
    
    Args:
        file_name (str): name of covid-19 data file
        file_path (str): path to covid-19 data file

    Returns:
        this function does not return anything
    '''
    
    file_full_path = os.path.join(file_path, file_name)

    try:
        # get the time of last modification of the specified path; the getmtime method returns 
        # a floating point value which represents the number of seconds since the epoch. 
        # This method raise OSError if the file does not exist or is somehow inaccessible.
        mtime = os.path.getmtime(file_full_path)
        
        # converting floating point value to a datetime date
        last_modified_date = dt.datetime.fromtimestamp(mtime).date()
        
        # compare last_modified_date of current file with today's date and only initiate sequence 
        # if the current data file is indeed old, ie. it was last modified yesterday or earlier
        today_date = dt.date.today()
        
        if last_modified_date == today_date:
            print("We already have the latest data")
            
        elif last_modified_date < today_date:
            print('STARTING sequence for updating data...')
            print()
            
            archive_data(file_name, file_path)
            
            download_data(file_name, file_path)
            
            extract_zip_file(file_name, file_path)
            
            print()
            print('COMPLETED sequence for updating data successfully!')
        else:
            print('Error: Not able to comprehend; last_modified_date set to the future')
        
    except OSError:
        print('Error: Not able to extract meta data for provided file_name/file_path')

# %% [markdown]
# Running the below cell initiates the sequence of updating the covid-19 data:

# %%
# update data
get_latest_data(DATA_NAME, DATA_FOLDER_PATH)
# Out:
# STARTING sequence for updating data...
#
# - Old data file archived as: 'covid_19_data200708.csv'
#
# Downloading 494724%2F1319658%2Fcompressed%2Fcovid_19_data.csv.zip to ./data
# 100%|████████████████████████████████████████| 887k/887k [00:00<00:00, 5.07MB/s]
# 100%|████████████████████████████████████████| 887k/887k [00:00<00:00, 5.05MB/s]
#
# - New file extracted from compressed file to data folder as: 'covid_19_data.csv'
#
# - Zip file deleted post extraction.
#
# COMPLETED sequence for updating data successfully!

# %% [markdown]
# The next two functions are simply for reading our csv files. One with population data and one with covid-19 data.

# %%
def get_popdata(popdata_path = POPDATA_PATH):
    '''
    This function reads the population data from csv file into a pandas DataFrame, cleans up the
    column names and transforms 'Urban population ratio' data to type Float. 
    
    The data contains the following on country-level:
    
    - Country name
    - ISO code as described in the ISO 3166 international standard, the 3-letter version ('Short') 
    - Continent
    - Population
    - Population per square kilometer
    - Median age
    - Urban population ratio
    
    Args
        popdata_path (str): path to the population data file

    Returns:
        df_pop (dataframe): population dataframe
    '''
    
    # population dataset read into dataframe
    df_pop = pd.read_csv(popdata_path, delimiter=";") 
    
    # setting column headers
    df_pop.columns = ['Country', 'ISO', 'Continent', 'Population', 'Pop_km2', 'Median_age', 'Urban_Population_percent']
    
    # extracting the ratio from string column 'UrbanPopPercent' and replacing it with a new column with
    # float values for ratio.
    df_pop['Urban_Population_ratio'] = df_pop['Urban_Population_percent'].str.strip('%').astype(float).div(100)
    df_pop.drop('Urban_Population_percent', axis = 1, inplace=True)
    
    return df_pop

# %%
def get_covid_data(data_path = DATA_PATH):
    '''
    This function reads the covid-19 data from csv file into a pandas DataFrame, cleans up the
    column names and updates some of the country names to match the ones used in the population dataset. 
    
    The data contains the following on country-level:
    - Country name
    - Date (Daily. The start date is not the same for all countries; it ranges from January to March 2020)
    - Deaths (total number for respective country at respective date)
    
    Args:
        data_path (str): path to covid-19 data file

    Returns:
        this function does not return anything
    '''
    
    df = pd.read_csv(data_path) # population dataset read into dataframe
    
    # clean data
    
    df = df.rename(columns={"ObservationDate": "Date", "Country/Region": "Country"})
    
    df = df.groupby(['Country', 'Date']).sum().reset_index()
    
    # update some of the country names to match the ones used in the population dataset
    
    df['Country'] = df['Country'].replace({'UK': 'United Kingdom', 
                                           'US': 'United States', 
                                           'Mainland China': 'China',
                                           'Czech Republic': 'Czechia',
                                           'Burma': 'Myanmar'
                                           })
    try:
        df['Country'] = df['Country'].replace({"('St. Martin',)": "St. Martin",
                                               "occupied Palestinian territory": "Palestine",
                                               "State of Palestine": "Palestine",
                                               "Ivory Coast": "Cote d'Ivoire",
                                               "Gambia, The": "Gambia",
                                               "The Gambia": "Gambia",
                                               "The Bahamas": "Bahamas",
                                               "Bahamas, The": "Bahamas",
                                               "Republic of Ireland": "Ireland",
                                               "Republic of the Congo": "Congo (Brazzaville)",
                                               " Azerbaijan": "Azerbaijan"
                                              
                                              })
    except:
        pass
        
    # sort on Country, then Date. Mostly it is only one row getting grouped, whereever data is on regional
    # groupby ensures we get the data summed up to country level
    df_covid = df.groupby(['Country', 'Date']).sum().reset_index()
    
    # dropping columns we will not use.
    df_covid.drop(['SNo', 'Confirmed', 'Recovered'], axis=1, inplace=True)
    
    df_covid.columns = ['Country', 'Date', 'Total_deaths']
    
    return df_covid

# %%
df_pop = get_popdata()
df_pop.head()
# Out:
#        Country  ISO Continent  Population  Pop_km2  Median_age  \
# 0  Afghanistan  AFG      Asia    38928346       60          18
# 1      Albania  ALB    Europe     2877797      105          36
# 2      Algeria  DZA    Africa    43851044       18          29
# 3       Angola  AGO    Africa    32866272       26          17
# 4    Argentina  ARG   America    45195774       17          32
#
#    Urban_Population_ratio
# 0                    0.25
# 1                    0.63
# 2                    0.73
# 3                    0.67
# 4                    0.93

# %%
df_covid = get_covid_data()
df_covid.head()
# Out:
#        Country        Date  Total_deaths
# 0  Afghanistan  02/24/2020           0.0
# 1  Afghanistan  02/25/2020           0.0
# 2  Afghanistan  02/26/2020           0.0
# 3  Afghanistan  02/27/2020           0.0
# 4  Afghanistan  02/28/2020           0.0

# %%
# Countries not found in df_covid, assumed as 'not reporting'
s1 = df_pop.Country
s2 = df_covid.Country

s1[~s1.isin(s2)].reset_index(drop=True).squeeze()
# Out:
# 0     North Korea
# 1    Turkmenistan
# Name: Country, dtype: object

# %%
# Countries not available in df_pop (micro states, low population states, no population data etc.)
# I am leaving these out, as it would require too much manual work.

s2[~s2.isin(s1)].to_frame().groupby('Country').count().reset_index().squeeze()
# Out:
# 0                              Andorra
# 1                  Antigua and Barbuda
# 2                                Aruba
# 3                              Bahamas
# 4                              Bahrain
# 5                             Barbados
# 6                               Belize
# 7                               Bhutan
# 8                               Brunei
# 9                           Cabo Verde
# 10                          Cape Verde
# 11                      Cayman Islands
# 12                     Channel Islands
# 13                             Comoros
# 14                             Curacao
# 15                    Diamond Princess
# 16                            Djibouti
# 17                            Dominica
# 18                          East Timor
# 19                   Equatorial Guinea
# 20                            Eswatini
# 21                       Faroe Islands
# 22                                Fiji
# 23                       French Guiana
# 24                           Gibraltar
# 25                             Grenada
# 26                          Guadeloupe
# 27                                Guam
# 28                            Guernsey
# 29                       Guinea-Bissau
# 30                              Guyana
# 31                            Holy See
# 32                              Jersey
# 33                              Kosovo
# 34                             Lesotho
# 35                          MS Zaandam
# 36                               Macau
# 37                            Maldives
# 38                               Malta
# 39                          Martinique
# 40                           Mauritius
# 41                             Mayotte
# 42                              Monaco
# 43                       North Ireland
# 44                              Others
# 45                             Reunion
# 46                    Saint Barthelemy
# 47               Saint Kitts and Nevis
# 48                         Saint Lucia
# 49    Saint Vincent and the Grenadines
# 50                          San Marino
# 51               Sao Tome and Principe
# 52                          Seychelles
# 53                          St. Martin
# 54                            Suriname
# 55                         Timor-Leste
# 56                 Trinidad and Tobago
# 57                        Vatican City
# 58                  West Bank and Gaza
# 59                      Western Sahara
# Name: Country, dtype: object

# %%
def merge_data():
    '''
    This function get the population data and the covid-19 data and merges it to one dataframe
    
    Args:
        None

    Returns:
        df_merged (dataframe): merged data
    '''
    
    df_pop = get_popdata()
    
    df_covid = get_covid_data()
    
    df_merged = df_covid.set_index('Country').join(df_pop.set_index('Country')).reset_index()
    
    df_merged.dropna(subset=['Population'], inplace=True)

    
    
    df_merged = df_merged[['Date', 'Continent', 'Country', 'ISO', 'Population', 'Urban_Population_ratio', 'Pop_km2', 'Median_age', 'Total_deaths']]
    
    df_merged.Date = pd.to_datetime(df_merged.Date, infer_datetime_format=True)
    
    return df_merged

# %%
df_merged = merge_data()
df_merged.head()
# Out:
#         Date Continent      Country  ISO  Population  Urban_Population_ratio  \
# 0 2020-02-24      Asia  Afghanistan  AFG  38928346.0                    0.25
# 1 2020-02-25      Asia  Afghanistan  AFG  38928346.0                    0.25
# 2 2020-02-26      Asia  Afghanistan  AFG  38928346.0                    0.25
# 3 2020-02-27      Asia  Afghanistan  AFG  38928346.0                    0.25
# 4 2020-02-28      Asia  Afghanistan  AFG  38928346.0                    0.25
#
#    Pop_km2  Median_age  Total_deaths
# 0     60.0        18.0           0.0
# 1     60.0        18.0           0.0
# 2     60.0        18.0           0.0
# 3     60.0        18.0           0.0
# 4     60.0        18.0           0.0

# %%
def add_calculated_cols(df_merged):
    '''
    This function adds some calculated columns to the dataframe 

    Args:
        df_merged (dataframe): df containing covid-19 data as well as population data

    Returns:
        df_full (dataframe): With new calculated columns added
    '''
    df = df_merged.copy()
    
    df['Total_deaths_per_100k'] = 100000*df['Total_deaths']/(df['Population'] + 1.0)
    
    df['Weekday'] = df['Date'].dt.weekday
    
    df['Year_week'] = df['Date'].dt.strftime('%G-%V')
    
    country_codes = df.ISO.unique().tolist()
    
    country_dfs = []
    
    for code in country_codes:
        
        notgrouped = df[df['ISO'] == code]
        notgrouped.set_index('Year_week')
        notgrouped['Total_deaths_yesterday'] = notgrouped['Total_deaths'].shift(1).fillna(0)
        notgrouped['Deaths'] = notgrouped['Total_deaths'] - notgrouped['Total_deaths_yesterday']
        notgrouped.drop(['Total_deaths_yesterday'], axis=1, inplace=True)
        notgrouped.set_index('Year_week', inplace=True)

        grouped = notgrouped.groupby(['Year_week']).sum()
        grouped.rename(columns={"Deaths": "Deaths_week"}, inplace=True)
        grouped['Deaths_lastweek'] = grouped['Deaths_week'].shift(1).fillna(0)
        grouped['Infection_rate'] =  (grouped['Deaths_week'] / grouped['Deaths_lastweek']).fillna(0).replace(np.inf, 0)
        grouped = grouped[['Deaths_week', 'Deaths_lastweek', 'Infection_rate']]

        regrouped = notgrouped.join(grouped)
        
        #regrouped.rename(columns={"Deaths": "Deaths_week"}, inplace=True)
        
        country_dfs.append(regrouped)
        
    df_full = pd.concat(country_dfs)
    
    df_full['Deaths_per_100k'] = 100000*df_full['Deaths']/(df_full['Population'] + 1.0)
    
    df_full.reset_index(inplace=True)
    
    return df_full

# %%
df_full = add_calculated_cols(df_merged)
df_full
# Out:
#       Year_week       Date Continent      Country  ISO  Population  \
# 0       2020-09 2020-02-24      Asia  Afghanistan  AFG  38928346.0
# 1       2020-09 2020-02-25      Asia  Afghanistan  AFG  38928346.0
# 2       2020-09 2020-02-26      Asia  Afghanistan  AFG  38928346.0
# 3       2020-09 2020-02-27      Asia  Afghanistan  AFG  38928346.0
# 4       2020-09 2020-02-28      Asia  Afghanistan  AFG  38928346.0
# ...         ...        ...       ...          ...  ...         ...
# 19581   2020-27 2020-07-04    Africa     Zimbabwe  ZWE  14862924.0
# 19582   2020-27 2020-07-05    Africa     Zimbabwe  ZWE  14862924.0
# 19583   2020-28 2020-07-06    Africa     Zimbabwe  ZWE  14862924.0
# 19584   2020-28 2020-07-07    Africa     Zimbabwe  ZWE  14862924.0
# 19585   2020-28 2020-07-08    Africa     Zimbabwe  ZWE  14862924.0
#
#        Urban_Population_ratio  Pop_km2  Median_age  Total_deaths  \
# 0                        0.25     60.0        18.0           0.0
# 1                        0.25     60.0        18.0           0.0
# 2                        0.25     60.0        18.0           0.0
# 3                        0.25     60.0        18.0           0.0
# 4                        0.25     60.0        18.0           0.0
# ...                       ...      ...         ...           ...
# 19581                    0.38     38.0        19.0           8.0
# 19582                    0.38     38.0        19.0           8.0
# 19583                    0.38     38.0        19.0           9.0
# 19584                    0.38     38.0        19.0           9.0
# 19585                    0.38     38.0        19.0           9.0
#
#        Total_deaths_per_100k  Weekday  Deaths  Deaths_week  Deaths_lastweek  \
# 0                   0.000000        0     0.0          0.0              0.0
# 1                   0.000000        1     0.0          0.0              0.0
# 2                   0.000000        2     0.0          0.0              0.0
# 3                   0.000000        3     0.0          0.0              0.0
# 4                   0.000000        4     0.0          0.0              0.0
# ...                      ...      ...     ...          ...              ...
# 19581               0.053825        5     1.0          2.0              0.0
# 19582               0.053825        6     0.0          2.0              0.0
# 19583               0.060553        0     1.0          1.0              2.0
# 19584               0.060553        1     0.0          1.0              2.0
# 19585               0.060553        2     0.0          1.0              2.0
#
#        Infection_rate  Deaths_per_100k
# 0                 0.0         0.000000
# 1                 0.0         0.000000
# 2                 0.0         0.000000
# 3                 0.0         0.000000
# 4                 0.0         0.000000
# ...               ...              ...
# 19581             0.0         0.006728
# 19582             0.0         0.000000
# 19583             0.5         0.006728
# 19584             0.5         0.000000
# 19585             0.5         0.000000
#
# [19586 rows x 17 columns]

# %%
def dates_choice(df, all_dates=False, weekly=False):
    '''
    This function selects dates based on input. There are three types
    
    1. Historic daily data (all_dates=True)
    2. Historic weekly data (weekly=True, all_dates=False)
    2. Latest date data (weekly=False, all_dates=False)
    
    The historic data will be suitable for performing time series analysis.
    
    The latest date data will be suitable to look at the overall picture (such as accumulated death 
    count per country).
    
    Args:
        df (dataframe): df containing covid-19 data as well as population data
        
        all_dates (boolean): Optional argument - True if you wish to get daily historic data
        
        weekly (boolean): Optional argument - True if you wish to get historic weekly data

    Returns:
        df (dataframe): Based on choices
    '''    
    
    if all_dates:
        
        # No filtering required since all_dates is requested
        
        pass
    
    else:
        
        if weekly:
            
            # we wish to filter on Sundays because that is always the last day of each 'Year_week' 
            # (for instance last day of week 20, 21, 22 etc. is always a Sunday). However, due to the
            # fact that earlier applied function 'add_calculated_cols' does a simple groupby('Year_week')
            # to obtain the aggregated weekly numbers, the first aggregation for each country will often 
            # be based on less than seven days. So before filtering we will change the value of those cases
            
            for i in range(df.shape[0]):
                
                # looping dataframe, which is sorted by country then date
                
                # check if the current row is the first of a new country
                
                if i == 0:
                    
                    new_country = True
                    
                else:
                    
                    if df.ISO[i] == df.ISO[i-1]:
                        
                        new_country = False
                        
                    else:
                        
                        new_country = True
                
                # if it is we find the row of the first '6', which could be on the current row
                # or any of the next six rows.
                # We change its value unless the weekday is '0' (in which case the first '6' will 
                # be the seventh element, and we do not have to change its value)
                
                if new_country:
                    
                    wd = df.Weekday[i]
                    
                    if wd > 0:
                        
                        diff = 6 - wd
                        df.Weekday[i + diff] = 0
            
            # Finally we filter the dataframe on Sundays
            
            df = df[df.Weekday == 6]
            
        else:
            
            # In this case we have neither asked for all dates nor weekly dates,
            # which means we will get the last date only.
            
            df = df[df.Date == df.Date.max()].reset_index(drop=True)
            
            
    # we set the dates as index and make sure it is in datetime format    
        
    df = df.reset_index(drop=True).set_index('Date')
    df.index = pd.to_datetime(df.index, infer_datetime_format=True)
            
    return df

# %%
range(df_current.shape[0])
# Out:
# range(0, 19586)

# %%
df_current = dates_choice(df_full, all_dates=False, weekly=False)
df_current
# Out:
#            Year_week Continent                   Country  ISO    Population  \
# Date
# 2020-07-08              0.0        0.000000         0.000000
# 2020-07-08             36.0        0.777778         0.031928
# 2020-07-08            140.0        0.442857         0.346560
# 2020-07-08              3.0        0.333333         0.000000
# 2020-07-08              4.0        0.250000         0.000000
# 2020-07-08              0.0        0.000000         0.000000
# 2020-07-08              1.0        1.000000         0.010485
# 2020-07-08              0.0        0.000000         0.000000
# 2020-07-08              0.0        0.000000         0.000000
# 2020-07-08              1.0        0.000000         0.000000
# 2020-07-08              0.0        0.000000         0.000000
# 2020-07-08            128.0        0.445312         0.026085
# 2020-07-08              0.0        0.000000         0.000000
# 2020-07-08            123.0        0.471545         0.054878
# 2020-07-08             10.0        0.400000         0.010111
# 2020-07-08            671.0        0.442623         0.185605
# 2020-07-08           4144.0        0.567809         0.247732
# 2020-07-08              1.0        1.000000         0.000000
# 2020-07-08             12.0        0.916667         0.011951
# 2020-07-08             21.0        0.476190         0.014067
# 2020-07-08              0.0        0.000000         0.000000
# 2020-07-08             36.0        0.361111         0.010058
# 2020-07-08              8.0        1.500000         0.000000
# 2020-07-08              2.0        0.500000         0.000000

# %% [markdown]
# Now that we have the current total numbers ready let's print out some interesting rankings!

# %%
# Continent wise distribution

Countries_per_continent = df_current.groupby('Continent').count()['Country'].sort_values(ascending=False)

print("\nTotal number of countries included: {}\n".format(Countries_per_continent.sum()))

print(Countries_per_continent)
print()

# Urban Population ratio: High vs. Low

print('\nTop 15 in Urban Population ratio:\n')
print(df_current.sort_values('Urban_Population_ratio', ascending=False)[:15][['Country', 'Urban_Population_ratio', 'Deaths_per_100k']].to_string(index=False))

print()

print('\nBottom 5 in Urban Population ratio:\n')
print(df_current.sort_values('Urban_Population_ratio')[:5][['Country', 'Urban_Population_ratio', 'Deaths_per_100k']].to_string(index=False))

print()

# Median Age: High vs. Low

print('\nTop 15 in Median Age:\n')
print(df_current.sort_values('Median_age', ascending=False)[:15][['Country', 'Median_age', 'Deaths_per_100k']].to_string(index=False))

print()

print('\nBottom 5 in Median Age:\n')
print(df_current.sort_values('Median_age')[:5][['Country', 'Median_age', 'Deaths_per_100k']].to_string(index=False))
# Out:
# Total number of countries included: 151
#
# Continent
# Africa     44
# Europe     41
# Asia       40
# America    23
# Oceania     3
# Name: Country, dtype: int64
#
#
# Top 15 in Urban Population ratio:
#
#      Country  Urban_Population_ratio  Deaths_per_100k
#    Singapore                    1.00         0.000000
#    Hong Kong                    1.00         0.000000
#      Belgium                    0.98         0.017257
#        Qatar                    0.96         0.139328
#      Uruguay                    0.96         0.000000
#      Iceland                    0.94         0.000000
#    Argentina                    0.93         0.110630
#       Israel                    0.93         0.023107
#        Japan                    0.92         0.000791
#  Netherlands                    0.92         0.017508
#       Jordan                    0.91         0.000000
#      Denmark                    0.88         0.000000
#       Brazil                    0.88         0.575369
#   Luxembourg                    0.88         0.000000
#       Sweden                    0.88         0.346560
#
#
# Bottom 5 in Urban Population ratio:
#
#           Country  Urban_Population_ratio  Deaths_per_100k
#  Papua New Guinea                    0.13         0.000000
#           Burundi                    0.14         0.000000
#     Liechtenstein                    0.15         0.000000
#             Niger                    0.17         0.000000
#            Malawi                    0.18         0.026137
#
#
# Top 15 in Median Age:
#
#      Country  Median_age  Deaths_per_100k
#        Japan        48.0         0.000791
#        Italy        47.0         0.024809
#       Greece        46.0         0.000000
#      Germany        46.0         0.016710
#     Portugal        46.0         0.019614
#     Bulgaria        45.0         0.071959
#     Slovenia        45.0         0.000000
#    Hong Kong        45.0         0.000000
#    Lithuania        45.0         0.000000
#        Spain        45.0         0.008555
#  South Korea        44.0         0.003901
#       Latvia        44.0         0.000000
#      Croatia        44.0         0.024359
#  Netherlands        43.0         0.017508
#      Romania        43.0         0.093566
#
#
# Bottom 5 in Median Age:
#
# Country  Median_age  Deaths_per_100k
#   Niger        15.0         0.000000
#    Mali        16.0         0.004938
#  Uganda        17.0         0.000000
#    Chad        17.0         0.000000
#  Angola        17.0         0.000000

# %%
top10 = df_current.sort_values(['Deaths_per_100k'], ascending=False)[:10]['Country'].tolist()
df_top = df_full[df_full['Country'].isin(top10)]
df_top = df_top[df_top['Date'] > '2020-03-16'].reset_index(drop=True)
df_top
# Out:
#            Date Continent  Country  ISO  Population  Urban_Population_ratio  \
# 0    2020-03-17    Europe  Armenia  ARM   2963243.0                    0.63
# 1    2020-03-18    Europe  Armenia  ARM   2963243.0                    0.63
# 2    2020-03-19    Europe  Armenia  ARM   2963243.0                    0.63
# 3    2020-03-20    Europe  Armenia  ARM   2963243.0                    0.63
# 4    2020-03-21    Europe  Armenia  ARM   2963243.0                    0.63
# ...         ...       ...      ...  ...         ...                     ...
# 1135 2020-07-04    Europe   Sweden  SWE  10099265.0                    0.88
# 1136 2020-07-05    Europe   Sweden  SWE  10099265.0                    0.88
# 1137 2020-07-06    Europe   Sweden  SWE  10099265.0                    0.88
# 1138 2020-07-07    Europe   Sweden  SWE  10099265.0                    0.88
# 1139 2020-07-08    Europe   Sweden  SWE  10099265.0                    0.88
#
#       Pop_km2  Median_age  Total_deaths  Total_deaths_per_100k  Deaths  \
# 0       104.0        35.0           0.0               0.000000     0.0
# 1       104.0        35.0           0.0               0.000000     0.0
# 2       104.0        35.0           0.0               0.000000     0.0
# 3       104.0        35.0           0.0               0.000000     0.0
# 4       104.0        35.0           0.0               0.000000     0.0
# ...       ...         ...           ...                    ...     ...
# 1135     25.0        41.0        5420.0              53.667267     0.0
# 1136     25.0        41.0        5420.0              53.667267     0.0
# 1137     25.0        41.0        5433.0              53.795989    13.0
# 1138     25.0        41.0        5447.0              53.934613    14.0
# 1139     25.0        41.0        5482.0              54.281173    35.0
#
#       Deaths_per_100k  Deaths_s7  Deaths_per_100k_s7  Deaths_week  \
# 0            0.000000        0.0            0.000000          0.0
# 1            0.000000        0.0            0.000000          0.0
# 2            0.000000        0.0            0.000000          0.0
# 3            0.000000        0.0            0.000000          0.0
# 4            0.000000        0.0            0.000000          0.0
# ...               ...        ...                 ...          ...
# 1135         0.000000       20.0            0.198034        140.0
# 1136         0.000000       20.0            0.198034        140.0
# 1137         0.128722       17.0            0.168329        123.0
# 1138         0.138624       16.0            0.158427        114.0
# 1139         0.346560       16.0            0.158427        112.0
#
#       Deaths_lastweek  Infection_rate
# 0                 0.0        0.000000
# 1                 0.0        0.000000
# 2                 0.0        0.000000
# 3                 0.0        0.000000
# 4                 0.0        0.000000
# ...               ...             ...
# 1135            227.0        0.616740
# 1136            227.0        0.616740
df_nordic = df_full[df_full['Country'].isin(['Norway', 'Sweden', 'Denmark', 'Finland'])]
df_nordic = df_nordic[df_nordic['Date'] > '2020-03-16'].reset_index(drop=True)
df_nordic
# Out:
#           Date Continent  Country  ISO  Population  Urban_Population_ratio  \
# 0   2020-03-17    Europe  Denmark  DNK   5792202.0                    0.88
# 1   2020-03-18    Europe  Denmark  DNK   5792202.0                    0.88
# 2   2020-03-19    Europe  Denmark  DNK   5792202.0                    0.88
# 3   2020-03-20    Europe  Denmark  DNK   5792202.0                    0.88
# 4   2020-03-21    Europe  Denmark  DNK   5792202.0                    0.88
# ..         ...       ...      ...  ...         ...                     ...
# 451 2020-07-04    Europe   Sweden  SWE  10099265.0                    0.88
# 452 2020-07-05    Europe   Sweden  SWE  10099265.0                    0.88
# 453 2020-07-06    Europe   Sweden  SWE  10099265.0                    0.88
# 454 2020-07-07    Europe   Sweden  SWE  10099265.0                    0.88
# 455 2020-07-08    Europe   Sweden  SWE  10099265.0                    0.88
#
#      Pop_km2  Median_age  Total_deaths  Total_deaths_per_100k  Deaths  \
# 0      137.0        42.0           4.0               0.069058     1.0
# 1      137.0        42.0           4.0               0.069058     0.0
# 2      137.0        42.0           6.0               0.103588     2.0
# 3      137.0        42.0           9.0               0.155381     3.0
# 4      137.0        42.0          13.0               0.224440     4.0
# ..       ...         ...           ...                    ...     ...
# 451     25.0        41.0        5420.0              53.667267     0.0
# 452     25.0        41.0        5420.0              53.667267     0.0
# 453     25.0        41.0        5433.0              53.795989    13.0
# 454     25.0        41.0        5447.0              53.934613    14.0
# 455     25.0        41.0        5482.0              54.281173    35.0
#
#      Deaths_per_100k  Deaths_s7  Deaths_per_100k_s7  Deaths_week  \
# 0           0.017265        0.0            0.000000          4.0
# 1           0.000000        0.0            0.000000          4.0
# 2           0.034529        0.0            0.000000          6.0
# 3           0.051794        1.0            0.017265          9.0
# 4           0.069058        1.0            0.017265         12.0
# ..               ...        ...                 ...          ...
# 451         0.000000       20.0            0.198034        140.0
# 452         0.000000       20.0            0.198034        140.0
# 453         0.128722       17.0            0.168329        123.0
# 454         0.138624       16.0            0.158427        114.0
# 455         0.346560       16.0            0.158427        112.0
#
#      Deaths_lastweek  Infection_rate
# 0                0.0        0.000000
# 1                0.0        0.000000
# 2                0.0        0.000000
# 3                0.0        0.000000
# 4                1.0       12.000000
# ..               ...             ...
# 451            227.0        0.616740
# 452            227.0        0.616740
# 453            188.0        0.654255
# 454            172.0        0.662791
# 455            161.0        0.695652
#
# [456 rows x 17 columns]

# %%
dfx = dates_choice(df_nordic, all_dates=True)

idx = []

for _, ind in enumerate(dfx.index):
    d = (ind - dfx.index[0]).days%7
    if d == 0:
       idx.append(ind.date()) 

df = dfx[dfx.index.isin(idx)]

# %%
df.loc[df.Country == 'Sweden', 'Population'][0]
# Out:
# 10099265.0

# %%
df_historical = get_dates(df_full, all_dates=True)
df_historical = add_calculated_cols(df_historical)
df_historical.head()
# Out:
#            Continent      Country  ISO  Population  Urban_Population_ratio  \
# Date
# 2020-01-23          0.0              0.0             0.0                 0.0
# 2020-01-24          0.0              0.0             0.0                 0.0
# 2020-01-25          0.0              0.0             0.0                 0.0
# 2020-01-26          0.0              0.0             0.0                 0.0
# ...                 ...              ...             ...                 ...
# 2020-07-04        302.0            302.0           151.0                 0.0
# 2020-07-05        302.0              0.0             0.0                 0.0
# 2020-07-06        302.0            151.0           302.0                 0.0
# 2020-07-07        302.0            151.0           302.0                 0.0
# 2020-07-08        302.0            151.0           302.0                 0.0
#
# [169 rows x 12 columns]

# %%
sweden = df_historical[df_historical.Country == 'Sweden']
norway = df_historical[df_historical.Country == 'Norway']
usa = df_historical[df_historical.Country == 'United States']
italy = df_historical[df_historical.Country == 'Italy']
germany = df_historical[df_historical.Country == 'Germany']

sweden.tail()
# Out:
#            Continent Country  ISO  Population  Urban_Population_ratio  \
# Date
# 2020-07-04    Europe  Sweden  SWE  10099265.0                    0.88
# 2020-07-05    Europe  Sweden  SWE  10099265.0                    0.88
# 2020-07-06    Europe  Sweden  SWE  10099265.0                    0.88
# 2020-07-07    Europe  Sweden  SWE  10099265.0                    0.88
# 2020-07-08    Europe  Sweden  SWE  10099265.0                    0.88
#
#             Pop_km2  Median_age  Total_deaths  Total_deaths_per_100k  Deaths  \
# Date
# 2020-07-04     25.0        41.0        5420.0              53.667267     1.0
# 2020-07-05     25.0        41.0        5420.0              53.667267     0.0
# 2020-07-06     25.0        41.0        5433.0              53.795989     1.0
# 2020-07-07     25.0        41.0        5447.0              53.934613     0.0
# 2020-07-08     25.0        41.0        5482.0              54.281173     0.0
#
#             Deaths_per_100k  Deaths_s7  Deaths_per_100k_s7  Deaths_week  \
# Date
# 2020-07-04         0.006728        0.0                 0.0          2.0
# 2020-07-05         0.000000        0.0                 0.0          2.0
# 2020-07-06         0.006728        0.0                 0.0          2.0
# 2020-07-07         0.000000        0.0                 0.0          2.0
# 2020-07-08         0.000000        0.0                 0.0          2.0
#
#             Deaths_lastweek  Infection_rate
# Date
# 2020-07-04              2.0             1.0
# 2020-07-05              0.0             0.0
# 2020-07-06              1.0             2.0
# 2020-07-07              1.0             2.0
# 2020-07-08              1.0             2.0

# %%
df_neighbors = df_historical[df_historical.Country.isin(['Norway', 'Denmark', 'Finland'])]
pop_neighbors = df_neighbors.sort_values(by='Date')['Population'][-3:].sum()
neighbors = df_neighbors.groupby('Date').sum().drop(['Deaths_per_100k', 'Deaths_per_100k_s7'], axis=1)
neighbors['Deaths_per_100k'] = 100000*neighbors['Deaths']/pop_neighbors
neighbors['Deaths_per_100k_s7'] = 100000*neighbors['Deaths_s7']/pop_neighbors
neighbors.head()
# Out:
#             Population  Urban_Population_ratio  Pop_km2  Median_age  \
# Date
# 2020-01-29   5540720.0                    0.86     18.0        43.0
# 2020-01-30   5540720.0                    0.86     18.0        43.0
# 2020-01-31   5540720.0                    0.86     18.0        43.0
# 2020-02-01   5540720.0                    0.86     18.0        43.0
# 2020-02-02   5540720.0                    0.86     18.0        43.0
#
#             Total_deaths  Total_deaths_per_100k  Deaths  Deaths_s7  \
# Date
# 2020-01-29           0.0                    0.0     0.0        0.0
# 2020-01-30           0.0                    0.0     0.0        0.0
# 2020-01-31           0.0                    0.0     0.0        0.0
# 2020-02-01           0.0                    0.0     0.0        0.0
# 2020-02-02           0.0                    0.0     0.0        0.0
#
#             Deaths_week  Deaths_lastweek  Infection_rate  Deaths_per_100k  \
# Date
# 2020-01-29          0.0              0.0             0.0              0.0
# 2020-01-30          0.0              0.0             0.0              0.0
# 2020-01-31          0.0              0.0             0.0              0.0
# 2020-02-01          0.0              0.0             0.0              0.0
# 2020-02-02          0.0              0.0             0.0              0.0
#
#             Deaths_per_100k_s7
# Date
# 2020-01-29                 0.0
# 2020-01-30                 0.0
# 2020-01-31                 0.0
# 2020-02-01                 0.0
# 2020-02-02                 0.0

# %%
clist = df_historical.Country.unique().tolist()
n = len(df_historical.Country.unique().tolist())

randomc = clist[np.random.randint(1,n)]

data = df_historical[df_historical.Country == randomc]

print('Random country out of all {}: {}'.format(n, randomc))

data.Deaths_per_100k_s7.plot(figsize=(10,5));
# Out:
# Random country out of all 154: Cameroon

# %%
world.Deaths_per_100k_s7.plot(figsize=(10,5));

# %%
sweden.Deaths_per_100k_s7.plot(figsize=(10,5));

# %%
plt.figure(figsize=(12,7))
plt.xlabel('Date')
plt.ylabel('Deaths per 100,000 people')


ax1 = sweden.New_deaths_per_100k_s7.plot(color='red', grid=True, label='Sweden')
ax2 = neighbors.New_deaths_per_100k_s7.plot(color='blue', grid=True, label='Neighbors')

plt.legend()

plt.show()

# %%
plt.figure(figsize=(12,7))
plt.xlabel('Date')
plt.ylabel('Deaths per 100,000 people')

ax1= sweden.New_deaths_per_100k_s7.plot(color='red', grid=True, label='Sweden')
ax2 = norway.New_deaths_per_100k_s7.plot(color='blue', grid=True, label='Norway')


plt.legend()

plt.show()

# %%
plt.figure(figsize=(12,7))
plt.xlabel('Date')
plt.ylabel('Deaths per 100,000 people')

ax1= sweden.New_deaths_per_100k_s7.plot(color='red', grid=True, label='Sweden')
ax2 = usa.New_deaths_per_100k_s7.plot(color='blue', grid=True, label='USA')


plt.legend()

plt.show()

# %%
plt.figure(figsize=(12,7))
plt.xlabel('Date')
plt.ylabel('Deaths per 100,000 people')

ax1= sweden.New_deaths_per_100k_s7.plot(color='red', grid=True, label='Sweden')
ax2 = italy.New_deaths_per_100k_s7.plot(color='blue', grid=True, label='Italy')


plt.legend()

plt.show()

# %%
italy.New_deaths_per_100k_s7.plot();

# %%
def select_continent(df, continent):
    '''
    This function filters the dataframe on a single continent
    
    Args:
        df (dataframe): Dataset including a column 'Continent'
        continent (string): Name of continent. Valid values are found in below list

    Returns:
        df_continent (dataframe): Dataframe with only data from a single contintent
    '''
    if continent:
        
        continent_list = ['America', 'Europe', 'Asia', 'Africa', 'Oceania']
        
        assert continent in continent_list, "Continent is not in continent_list"
            
        df_continent = df[df['Continent'] == continent]
        
    return df_continent

# %%
europe = select_continent(df_current, 'Europe')
europe.head()
# Out:
#            Year_week Continent  Country  ISO  Population  \
# Date
# 2020-07-08   2020-28    Europe  Albania  ALB   2877797.0
# 2020-07-08   2020-28    Europe  Armenia  ARM   2963243.0
# 2020-07-08   2020-28    Europe  Austria  AUT   9006398.0
# 2020-07-08   2020-28    Europe  Belarus  BLR   9449323.0
# 2020-07-08   2020-28    Europe  Belgium  BEL  11589623.0
#
#             Urban_Population_ratio  Pop_km2  Median_age  Total_deaths  \
# Date
# 2020-07-08                    0.63    105.0        36.0          83.0
# 2020-07-08                    0.63    104.0        35.0         521.0
# 2020-07-08                    0.57    109.0        43.0         706.0
# 2020-07-08                    0.79     47.0        40.0         443.0
# 2020-07-08                    0.98    383.0        42.0        9776.0
#
#             Total_deaths_per_100k  Weekday  Deaths  Deaths_week  \
# Date
# 2020-07-08               2.884150        2     2.0          7.0
# 2020-07-08              17.582082        2    18.0         37.0
# 2020-07-08               7.838871        2     0.0          0.0
# 2020-07-08               4.688166        2     7.0         20.0
# 2020-07-08              84.351313        2     2.0          5.0
#
#             Deaths_lastweek  Infection_rate  Deaths_per_100k
# Date
# 2020-07-08             21.0        0.333333         0.069498
# 2020-07-08             58.0        0.637931         0.607442
# 2020-07-08              4.0        0.000000         0.000000
# 2020-07-08             40.0        0.500000         0.074079
# 2020-07-08             39.0        0.128205         0.017257

# %%
def rank_data(df_current, top_n = (None, None)):
    '''
    This function filters on the top n countries ranked on any of the following:
    
    - Population
    - Pop_km2
    - Urban_Population_ratio
    - Median_age
    - Deaths
    - Deaths_per_100k
    
    Args:
        df_current (dataframe): dataframe with just the latest date
        top_n (tuple): First element (str): variable name to base the ranking on
                        Second element (int): the n in top_n 


    Returns:
        df (dataframe): ranked data
    '''
    
    var_list = ['Population', 'Pop_km2', 'Urban_Population_ratio', 'Median_age', 'Total_deaths', \
                'Total_deaths_per_100k', 'Deaths', 'Deaths_per_100k', 'Deaths_s7', 'Deaths_per_100k_s7', 
                'Deaths_week', 'Deaths_lastweek', 'Infection_rate']
    
    # unpack tuple
    
    var = top_n[0]
    n = top_n[1]
    
    assert var in var_list
    
    # limiting n so that it is not more than the number of rows (capped)
    
    if n:
        tot_countries = df_current.shape[0]
        if n > tot_countries:
            n = tot_countries
            
    df = df_current.sort_values(by=[var], ascending=False)[:n]
    
    return df

# %%
rank_data(df_current, top_n = ('Population', 2))
# Out:
#            Year_week Continent Country  ISO    Population  \
# Date
# 2020-07-08   2020-28      Asia   China  CHN  1.439324e+09
# 2020-07-08   2020-28      Asia   India  IND  1.380004e+09
#
#             Urban_Population_ratio  Pop_km2  Median_age  Total_deaths  \
# Date
# 2020-07-08                    0.61    153.0        38.0        4634.0
# 2020-07-08                    0.35    464.0        28.0       21129.0
#
#             Total_deaths_per_100k  Weekday  Deaths  Deaths_week  \
# Date
# 2020-07-08               0.321957        2     0.0          0.0
# 2020-07-08               1.531082        2   487.0       1436.0
#
#             Deaths_lastweek  Infection_rate  Deaths_per_100k
# Date
# 2020-07-08              0.0         0.00000          0.00000
# 2020-07-08           3218.0         0.44624          0.03529

# %%
def prepare_barplot(continent=None, top_n = (None, None)):
    '''
    This funtion gets the current high level aggregated data suitable for bar plots.
    It is optional to filter on continent.
    It is also optional to filter on the top n countries ranked on any of the following:
    
    - Population
    - Pop_km2
    - Urban_Population_ratio
    - Median_age
    - Deaths
    - Deaths_per_100k
    
    Args:
        continent (str): The continent ('America', 'Europe', 'Asia', 'Africa', 'Oceania')
        top_n (tuple): First element (str): variable name to base the ranking on
                        Second element (int): the n in top_n 

    Returns:
        df_current (dataframe): dataframe with just the latest date prepared for barplot
    '''

    df_merged = merge_data()
    
    df_full = add_calculated_cols(df_merged)
    
    df_current = dates_choice(df_full)
    
    if continent:
        df_current = select_continent(df_current, continent)
        
    var_list = ['Population', 'Pop_km2', 'Urban_Population_ratio', 'Median_age', 'Total_deaths', \
                'Total_deaths_per_100k', 'Deaths', 'Deaths_per_100k', 'Deaths_s7', 'Deaths_per_100k_s7', \
                'Deaths_week', 'Deaths_lastweek', 'Infection_rate']
    
    # assert that top_n tuple input is valid in case two (no-None) elements are provided
    
    if (len(top_n) == 2) and (top_n[0] and top_n[1]):
        
        assert top_n[0] in var_list, "First tuple element in 'top_n' must be in var_list and of type String"
        assert isinstance(top_n[1], int) == True, "Second tuple element in 'top_n' must of type Integer"
    
        df_current = rank_data(df_current, top_n)
        
    df_current = df_current.reset_index().set_index('Country')
    
    return df_current

# %%
# Test: Prepare_barplot of Top 20 Deaths_per_100k in Asia

var = 'Total_deaths_per_100k'

df = prepare_barplot(top_n = ('Total_deaths_per_100k', 10))

df = df[[var]]

df
# Out:
#                 Total_deaths_per_100k
# Country
# Belgium                     84.351313
# United Kingdom              65.701311
# Spain                       60.733898
# Italy                       57.745526
# Sweden                      54.281173
# France                      45.862401
# United States               39.969468
# Netherlands                 35.915060
# Ireland                     35.197954
# Chile                       34.384445

# %%
def prepare_timeplot(continent=None, top_n = (None, None)):
    '''
    This funtion gets the daily data suitable for time series plots.
    It is optional to filter on continent.
    It is also optional to filter on the top n countries ranked on any of the following:
    
    - Population
    - Pop_km2
    - Urban_Population_ratio
    - Median_age
    - Deaths
    - Deaths_per_100k
    
    Args:
        file_name (str): name of covid-19 data file
        file_path (str): path to covid-19 data file

    Returns:
        this function does not return anything
    '''

    df_merged = merge_data()
    
    df_full = add_calculated_cols(df_merged)
    
    df = dates_choice(df_full, all_dates=True)
    
    df_current = dates_choice(df_full)
    
    if continent:
        df_current = select_continent(df_current, continent)
        
    var_list = ['Population', 'Pop_km2', 'Urban_Population_ratio', 'Median_age', 'Total_deaths', \
                'Total_deaths_per_100k', 'Deaths', 'Deaths_per_100k', 'Deaths_s7', 'Deaths_per_100k_s7', \
                'Deaths_week', 'Deaths_lastweek', 'Infection_rate']
    
    # assert that top_n tuple input is valid in case two (no-None) elements are provided
    
    if (len(top_n) == 2) and (top_n[0] and top_n[1]):
        
        assert top_n[0] in var_list, "First tuple element in 'top_n' must be in var_list and of type String"
        assert isinstance(top_n[1], int) == True, "Second tuple element in 'top_n' must of type Integer"
    
        df_current = rank_data(df_current, top_n)

    return df_current

# %%
def prepare_time(continent=None, top_n = (None, None)):

    

    df_merged = merge_data()
    
    df_full = add_calculated_cols(df_merged)
    
    df = dates_choice(df_full, all_dates=True)
    
    
    countries = df.Country.unique()


    # initializing the plot of df
    dic = dict()

    var = 'Total_deaths'
    group = 'Country'

    tot_countries = df.shape[0]

    
    
    
    if top_n[0] and top_n[1]:
    
        var = top_n[0]
        n = top_n[1]
        if n > tot_countries:
            n = tot_countries
    else:
        n = tot_countries


    last_date = df.index.max()

    df_last = df[df.index == last_date].sort_values(var, ascending=False)
    
    countrylist = list(df_last[group][:n])

    #df = df.reset_index()
    df = df[df[group].isin(countrylist)]


    return countrylist, df

# %%
countrylist, df = prepare_time(top_n=('Deaths', 10))
df
# Out:
#            Year_week Continent        Country  ISO   Population  \
# Date
# 2020-01-23   2020-04   America         Brazil  BRA  212559417.0
# 2020-02-26   2020-09   America         Brazil  BRA  212559417.0
# 2020-02-27   2020-09   America         Brazil  BRA  212559417.0
# 2020-02-28   2020-09   America         Brazil  BRA  212559417.0
# 2020-02-29   2020-09   America         Brazil  BRA  212559417.0
# ...              ...       ...            ...  ...          ...
# 2020-07-04   2020-27   America  United States  USA  331002651.0
# 2020-07-05   2020-27   America  United States  USA  331002651.0
# 2020-07-06   2020-28   America  United States  USA  331002651.0
# 2020-07-07   2020-28   America  United States  USA  331002651.0
# 2020-07-08   2020-28   America  United States  USA  331002651.0
#
#             Urban_Population_ratio  Pop_km2  Median_age  Total_deaths  \
# Date
# 2020-01-23                    0.88     25.0        33.0           0.0
# 2020-02-26                    0.88     25.0        33.0           0.0
# 2020-02-27                    0.88     25.0        33.0           0.0
# 2020-02-28                    0.88     25.0        33.0           0.0
# 2020-02-29                    0.88     25.0        33.0           0.0
# ...                            ...      ...         ...           ...
# 2020-07-04                    0.83     36.0        38.0      129676.0
# 2020-07-05                    0.83     36.0        38.0      129947.0
# 2020-07-06                    0.83     36.0        38.0      130285.0
# 2020-07-07                    0.83     36.0        38.0      131480.0
# 2020-07-08                    0.83     36.0        38.0      132300.0
#
#             Total_deaths_per_100k  Weekday  Deaths  Deaths_week  \
# Date
# 2020-01-23               0.000000        3     0.0          0.0
# 2020-02-26               0.000000        2     0.0          0.0
# 2020-02-27               0.000000        3     0.0          0.0
# 2020-02-28               0.000000        4     0.0          0.0
# 2020-02-29               0.000000        5     0.0          0.0
# ...                           ...      ...     ...          ...
# 2020-07-04              39.176725        5   242.0       4144.0
# 2020-07-05              39.258598        6   271.0       4144.0
# 2020-07-06              39.360712        0   338.0       2353.0
# 2020-07-07              39.721736        1  1195.0       2353.0
# 2020-07-08              39.969468        2   820.0       2353.0
#
#             Deaths_lastweek  Infection_rate  Deaths_per_100k
# Date
# 2020-01-23              0.0        0.000000         0.000000
# 2020-02-26              0.0        0.000000         0.000000
# 2020-02-27              0.0        0.000000         0.000000
# 2020-02-28              0.0        0.000000         0.000000
# 2020-02-29              0.0        0.000000         0.000000
# ...                     ...             ...              ...
# 2020-07-04           5826.0        0.711294         0.073111
# 2020-07-05           5826.0        0.711294         0.081872
# 2020-07-06           4144.0        0.567809         0.102114
# 2020-07-07           4144.0        0.567809         0.361024
# 2020-07-08           4144.0        0.567809         0.247732
#
# [1438 rows x 16 columns]

# %%
# Test: Prepare_timeplot

#var = 'Total_deaths_per_100k'

df = prepare_timeplot(top_n = ('Total_deaths_per_100k', 10))

#df = df[[var]]

df
# Out:
#            Year_week Continent         Country  ISO   Population  \
# Date
# 2020-07-08   2020-28    Europe         Belgium  BEL   11589623.0
# 2020-07-08   2020-28    Europe  United Kingdom  GBR   67886011.0
# 2020-07-08   2020-28    Europe           Spain  ESP   46754778.0
# 2020-07-08   2020-28    Europe           Italy  ITA   60461826.0
# 2020-07-08   2020-28    Europe          Sweden  SWE   10099265.0
# 2020-07-08   2020-28    Europe          France  FRA   65273511.0
# 2020-07-08   2020-28   America   United States  USA  331002651.0
# 2020-07-08   2020-28    Europe     Netherlands  NLD   17134872.0
# 2020-07-08   2020-28    Europe         Ireland  IRL    4937786.0
# 2020-07-08   2020-28   America           Chile  CHL   19116201.0
#
#             Urban_Population_ratio  Pop_km2  Median_age  Total_deaths  \
# Date
# 2020-07-08                    0.98    383.0        42.0        9776.0
# 2020-07-08                    0.83    281.0        40.0       44602.0
# 2020-07-08                    0.80     94.0        45.0       28396.0
# 2020-07-08                    0.69    206.0        47.0       34914.0
# 2020-07-08                    0.88     25.0        41.0        5482.0
# 2020-07-08                    0.82    119.0        42.0       29936.0
# 2020-07-08                    0.83     36.0        38.0      132300.0
# 2020-07-08                    0.92    508.0        43.0        6154.0
# 2020-07-08                    0.63     72.0        38.0        1738.0
# 2020-07-08                    0.85     26.0        35.0        6573.0
#
#             Total_deaths_per_100k  Weekday  Deaths  Deaths_week  \
# Date
# 2020-07-08              84.351313        2     2.0          5.0
# 2020-07-08              65.701311        2   126.0        297.0
# 2020-07-08              60.733898        2     4.0         11.0
# 2020-07-08              57.745526        2    15.0         53.0
# 2020-07-08              54.281173        2    35.0         62.0
# 2020-07-08              45.862401        2     0.0         40.0
# 2020-07-08              39.969468        2   820.0       2353.0
# 2020-07-08              35.915060        2     3.0          8.0
# 2020-07-08              35.197954        2    -4.0         -3.0
# 2020-07-08              34.384445        2   139.0        265.0
#
#             Deaths_lastweek  Infection_rate  Deaths_per_100k
# Date
# 2020-07-08             39.0        0.128205         0.017257
# 2020-07-08            671.0        0.442623         0.185605
# 2020-07-08             42.0        0.261905         0.008555
# 2020-07-08            123.0        0.430894         0.024809
# 2020-07-08            140.0        0.442857         0.346560
# 2020-07-08            115.0        0.347826         0.000000
# 2020-07-08           4144.0        0.567809         0.247732
# 2020-07-08             22.0        0.363636         0.017508
# 2020-07-08              6.0       -0.500000        -0.081008
# 2020-07-08            799.0        0.331665         0.727132

# %%
df = prepare_barplot()
df
# Out:
#                   Date Continent  ISO  Population  Urban_Population_ratio  \
# Country
# Afghanistan 2020-07-08      Asia  AFG  38928346.0                    0.25
# Albania     2020-07-08    Europe  ALB   2877797.0                    0.63
# Algeria     2020-07-08    Africa  DZA  43851044.0                    0.73
# Angola      2020-07-08    Africa  AGO  32866272.0                    0.67
# Argentina   2020-07-08   America  ARG  45195774.0                    0.93
# ...                ...       ...  ...         ...                     ...
# Venezuela   2020-07-08   America  VEN  28435940.0                    0.51
# Vietnam     2020-07-08      Asia  VNM  97338579.0                    0.38
# Yemen       2020-07-08      Asia  YEM  29825964.0                    0.38
# Zambia      2020-07-08    Africa  ZMB  18383955.0                    0.45
# Zimbabwe    2020-07-08    Africa  ZWE  14862924.0                    0.38
#
#              Pop_km2  Median_age  Total_deaths  Total_deaths_per_100k  Deaths  \
# Country
# Afghanistan     60.0        18.0         936.0               2.404418    16.0
# Albania        105.0        36.0          83.0               2.884150     2.0
# Algeria         18.0        29.0         978.0               2.230278    10.0
# Angola          26.0        17.0          21.0               0.063895     0.0
# Argentina       17.0        32.0        1694.0               3.748138    50.0
# ...              ...         ...           ...                    ...     ...
# Venezuela       32.0        30.0          75.0               0.263751     4.0
# Vietnam        314.0        32.0           0.0               0.000000     0.0
# Yemen           56.0        20.0         351.0               1.176827     3.0
# Zambia          25.0        18.0          42.0               0.228460     0.0
# Zimbabwe        38.0        19.0           9.0               0.060553     0.0
#
#              Deaths_week  Deaths_lastweek  Infection_rate
# Country
# Afghanistan         72.0            143.0        0.503497
# Albania              7.0             21.0        0.333333
# Algeria             26.0             55.0        0.472727
# Angola               2.0              8.0        0.250000
# Argentina          187.0            275.0        0.680000
# ...                  ...              ...             ...
# Venezuela           10.0             21.0        0.476190
# Vietnam              0.0              0.0             NaN
# Yemen               13.0             36.0        0.361111
# Zambia              12.0              8.0        1.500000
# Zimbabwe             1.0              2.0        0.500000
#
# [151 rows x 13 columns]

# %%
# Test: Prepare Choropleth
df = prepare_barplot()
var = 'Deaths_per_100k'

date = str(df.Date[0])[:10]
df = df[['ISO', var]]
print(date)
df
# Out:
# 2020-07-08
#              ISO  Deaths_per_100k
# Country
# Afghanistan  AFG         0.041101
# Albania      ALB         0.069498
# Algeria      DZA         0.022804
# Angola       AGO         0.000000
# Argentina    ARG         0.110630
# ...          ...              ...
# Venezuela    VEN         0.014067
# Vietnam      VNM         0.000000
# Yemen        YEM         0.010058
# Zambia       ZMB         0.000000
# Zimbabwe     ZWE         0.000000
#
# [151 rows x 2 columns]

# %% [markdown]
# ### Further exploration - not included in web app

# %% [markdown]
# Playing around with automatically generated titles based on choice of continent and top_n in as input.
#
# Earlier, when infection and recovery number were included, the bar chart could take on multiple variables. It still can, however, none of the var_lists have variables with similar magnitude of values.
#
# **Recommended: Some nice Choropleth map plots further down**

# %%
def plot_bar(continent=None, top_n = ('Deaths_per_100k', 10)):
    
    
    var = top_n[0]
    n = top_n[1]
    
    df = prepare_barplot(continent=continent, top_n = top_n)
    
    df.set_index('Country', inplace=True)

    var_list_rel = ['Deaths_per_100k']
    keyword1 = '_per_100k'
    
    var_list_pop = ['Population', 'Pop_km2', 'Urban_Population_ratio']
    keyword2 = 'Pop'
    
    var_list_abs = ['Deaths']

    if keyword1 in var:
        var_list = var_list_rel
    
    elif keyword2 in var:
        var_list = var_list_pop
        
    else:
        var_list = var_list_abs
        
        
    tot_countries = df.shape[0]
    if n > tot_countries:
        top_n = tot_countries

    # continent related:
    # adjusting fig_with for continent Oceania which have very few countries 
    
    if continent == 'Oceania':
        fig_width = 5
    else:
        fig_width = 20
        
            
    if not continent:
        continent = "The World"
    
    df.sort_values(by=[var], ascending=False).loc[:, var_list][:n].plot.bar(
        title = '{} Top {}: Number of {}'.format(continent, n, var), 
        stacked = False,
        colormap='tab20b',
        figsize=(fig_width, 5)
        )
    
    plt.xticks(rotation=20)
    plt.legend(loc='upper right');

# %% [markdown]
# ## Appendix

# %%
# plot for exploring in this notebook. Won't be in plotly
plot_bar(continent='', top_n = ('Deaths', 10))

# %%
def prepare_geo(df_current):
    
    fp = 'data/ne_10m_admin_0_countries.shp'

    gdf = gpd.read_file(fp)
    
    gdf = gdf.rename(columns={"ADMIN": "Country", "ADM0_A3": "Short"})
    
    gdf = gdf[['Country', 'Short', 'geometry']]
    gdf.columns = ['Country', 'ISO', 'geometry']
    
    
    df_all = df_current
    
    
    df = gdf.merge(df_all, how='left', on='ISO').drop(columns=['Date', 'Country_y'])
    
    df.rename(columns={"Country_x": "Country"}, inplace = True)
    
    df.fillna(0, inplace = True)
    
    return df

# %%
prepare_geo(df_current)

# %%
def plot_geo(colname, continent=None):
    
    
    data = prepare_geo(df_current)
    
    data = data[data.Country!="Antarctica"]

    if continent:
        data = data[data.Continent == continent] 

    fig, ax = plt.subplots(1, 1, figsize=(16, 12))
    
    
    if not continent:
        #ax.set(xlim=(-24, 40), ylim=(35, 75))
        fontsize = 6
    elif continent == 'Europe':
        ax.set(xlim=(-24, 40), ylim=(35, 75))
        fontsize = 8
        ax.text(1, 46, 'France', fontsize=fontsize)
        ax.text(8, 62, 'Norway', fontsize=fontsize)
        
    elif continent == 'America':
        ax.set(xlim=(-130, -30), ylim=(-55, 75))
        fontsize = 10     
        ax.text(-103, 38, 'USA', fontsize=fontsize)    
        ax.text(-107, 53, 'Canada', fontsize=fontsize)
    elif continent == 'Asia':
        ax.set(xlim=(20, 145), ylim=(-10, 75))
        fontsize = 8     
    else:
        fontsize = 8

    

    data.plot(column=colname, ax=ax, legend=True, cmap='Wistia', legend_kwds={'label': "{}".format(colname), 
                                                                      'orientation': "vertical"})

    plt.xlabel("Longitude")
    plt.ylabel("Latitude")
    #plt.xticks([10.7, 10.8, 10.9])
    #plt.yticks([59.8, 59.9, 60.0])
    #plt.suptitle('Marka', y=0.73, fontsize=10)

    plt.title('{}: {}\n'.format(continent, colname),  fontsize=18)
    
    #plt.axis('off')

    skip_list = ['Norway', 'France', 'United States of America', 'Canada']

    for idx, row in data.iterrows():
        
        if (len(str(row['Country'])) > 3) & (str(row['Country']) not in skip_list):
            plt.annotate(s=row['Country'], xy=row['geometry'].centroid.coords[0],
                     horizontalalignment='center', fontsize=fontsize)

# %%
plot_geo(colname = 'Deaths_per_100k', continent = 'Europe')

# %%
plot_geo(colname = 'Deaths_per_100k', continent = 'America')

# %%
plot_geo(colname = 'Deaths_per_100k', continent = 'Asia')
